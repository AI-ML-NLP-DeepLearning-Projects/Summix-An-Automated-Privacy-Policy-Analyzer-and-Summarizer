# %% [markdown]
# #Abstractive Summarization of Privacy Policies with Seq2Seq
# **FYP1**
# BY:
# SHAHZEB AND MUNEEB

# %% [markdown]
# The objective of this project is to build a model that can create relevant abstractive summaries for Privacy Policies preserving the original context.
# To build our model we will use a two-layered bidirectional RNN with LSTMs on the input data and two layers, each with an LSTM using attention on the target data.
# The sections of this project are:
#
# - Preparing the Data
# - Building the Model
# - Training the Model
# - Making Our Own Abstractive Summaries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re
from nltk.corpus import stopwords
import time
from tensorflow.python.layers.core import Dense
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# TensorFlow Version: 1.15.0

# %%
print('TensorFlow Version: {}'.format(tf.__version__))

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ### MOunt Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.getcwd()
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ## Exploring The Data set

# %%
headings = pd.read_csv('drive/My Drive/Colab Notebooks/newdatasetcopy.csv')

# %%
print(headings.shape)
print(headings.head())
# Out:
# (4904, 2)

# %%
# Out:
#                                              Summary                                             Policy
# 0  If the browser is loading a page and the serve...  Cookies are text files sent by Web servers to ...
# 1  The Weather Channel and its AffiliatesWe use i...  One of the most valuable assets of our busines...
# 2  When you enter sensitive financial information...  EA understands the importance of keeping your ...
# 3  We may also obtain information about you from ...  Activision only collects personal information ...
# 4  Session data is cleared when a browser is closed.  Pinkbike does not collect information from not...

# %%
# Check for any null values in the dataset
headings.isnull().sum()
# Out:
# Summary    0
# Policy     0
# dtype: int64

# %%
# Remove null values and unneeded features
headings = headings.dropna()

headings = headings.reset_index(drop=True)

# %%
headings.head()
# Out:
#                                              Summary                                             Policy
# 0  If the browser is loading a page and the serve...  Cookies are text files sent by Web servers to ...
# 1  The Weather Channel and its AffiliatesWe use i...  One of the most valuable assets of our busines...
# 2  When you enter sensitive financial information...  EA understands the importance of keeping your ...
# 3  We may also obtain information about you from ...  Activision only collects personal information ...
# 4  Session data is cleared when a browser is closed.  Pinkbike does not collect information from not...

# %%
# Inspecting some of the items from the dataset
for i in range(5):
    print("Extracted Summary#",i+1)
    print(headings.Summary[i])
    print("Original Paragraph#",i+1)
    print(headings.Policy[i])
    print()
# Out:
# Extracted Summary# 1
# If the browser is loading a page and the server requests the information stored in the cookie the cookie is sent back to the server.
# Original Paragraph# 1
# Cookies are text files sent by Web servers to Web browsers and are stored on the user's computer or mobile device. If the browser is loading a page and the server requests the information stored in the cookie the cookie is sent back to the server.Cookies contain data about the user's activities on the website and can be used by Web servers to identify and track users as they navigate different pages on a website and to identify users returning to a website.Cookies may be either "persistent" or "session" cookies. A persistent cookie will remain valid until its set expiration date (unless deleted by the user). A session cookie will expire at the end of the user session when the Web browser is closed.
#
# Extracted Summary# 2
# The Weather Channel and its AffiliatesWe use information collected on the Services and disclose information to third parties including your physical geographic location to help fulfill your requests or in connection with the operation of the Services for example to service your account conduct a transaction or provide a service that you have requested display information and advertisements that we believe match your interests and profile facilitate updates to the Services provide support notify you if you've won a contest or sweepstakes improve the working of the Services and compile statistics about our users and your use of the Services.
# Original Paragraph# 2
# One of the most valuable assets of our business is you. Except as described below The Weather Channel does not rent sell or share PII about you with other people or nonaffiliated companies.A. The Weather Channel and its AffiliatesWe use information collected on the Services and disclose information to third parties including your physical geographic location to help fulfill your requests or in connection with the operation of the Services for example to service your account conduct a transaction or provide a service that you have requested display information and advertisements that we believe match your interests and profile facilitate updates to the Services provide support notify you if you've won a contest or sweepstakes improve the working of the Services and compile statistics about our users and your use of the Services. We and such third parties may on occasion combine information about you with information obtained from other parties to market to you products or services that may be of interest to you.At various points we may provide you with the opportunity to opt-in to receive special offers from The Weather Channel and its affiliates. If you choose to opt in The Weather Channel and its affiliates will use your PII to inform you of other products or services available from The Weather Channel and its affiliates including WSI Corporation The Weather Underground LLC and Weather Central LP. These products may include for example schedules for special programs on The Weather Channel cable network or offers to purchase a calendar from The Weather Channel.B. Companies Offering Promotions Products or ServicesAt times we will provide you with the opportunity to opt-in to receive promotions products or services from third party sponsors. With your permission The Weather Channel will periodically send to you via e-mail offers and promotions from our third party sponsors which we select based upon your interests or user profile. In this case we do not share your information with the third party sponsors-we do the mailing for them. You will always have the opportunity to opt-out of receiving future offers by following the unsubscribe link included with each email. In other instances we provide you with the opportunity to receive products and services directly from specifically identified third parties through the Services. In these instances you must explicitly consent to receive each offer. When you explicitly agree to receive offers from specific third parties your information is shared with the specific third party to enable them to provide you with the offer you have requested. We are not responsible for the information collection practices of these third parties and all information provided is governed by the privacy policies of these third parties. You should review the privacy policies of these parties before supplying PII to them.C. Third-Party ProcessorsWhen your information is collected on the Services it may be collected directly by or shared with selected third parties in connection with the operation of the Services or the provision of services to you ("Third Party Processors"). These Third Party Processors may include for example companies that operate our online store that process credit card information or handle shipping for The Weather Channel that deliver materials to you via e-mail or postal service that organize administer process or provide advertising services and/or that analyze data on our behalf to help us provide more relevant offers to you and to eliminate the delivery of duplicate offers as well as correcting and/or updating users' data based on information we provide them. We also provide your information to third party mapping service providers to provide you map content for the Services. Third party processors are authorized to use your information that we provide to them only to carry out the service they are providing for The Weather Channel. We require that the third party processors securely  ...
#
# Extracted Summary# 3
# When you enter sensitive financial information (such as a credit card number) on our order forms we encrypt the transmission of that information using commercially reasonable methods.
# Original Paragraph# 3
# EA understands the importance of keeping your information safe and secure. EA will make commercially reasonable efforts to protect your personal information and ensure the security of our systems. When you enter sensitive financial information (such as a credit card number) on our order forms we encrypt the transmission of that information using commercially reasonable methods. No method of transmission over the Internet or method of electronic storage is 100% secure however. We cannot guarantee that your information will not be accessed disclosed altered or destroyed by breach of any of our physical technical or managerial safeguards. We cannot assume responsibility or liability for unauthorized access to our servers and systems.
#
# Extracted Summary# 4
# We may also obtain information about you from other sources as far as such other sources are legally entitled to share such information and combine that information with information we have collected from you.* Web Site RegistrationActivision may collect personal information from you when registering as a Web site member including your name address e-mail address and phone number.
# Original Paragraph# 4
# Activision only collects personal information from you on a voluntary basis. When you submit personal information to Activision it will usually take the form of: (1) Web site registration; (2) contests and promotions; (3) customer service; (4) demo downloads; (5) purchase of a product or service through our online stores; (6) use of a website or other online property (including Online Services (as defined below)); (7) online submission of your rÃ©sumÃ© for job openings. The information we collect may include personal information such as your name e-mail address phone number and home address. In addition we may collect demographic information such as your age gender and interests. We may also obtain information about you from other sources as far as such other sources are legally entitled to share such information and combine that information with information we have collected from you.* Web Site RegistrationActivision may collect personal information from you when registering as a Web site member including your name address e-mail address and phone number. We may also collect demographic information such as your gender and birth date which we may combine with your personal information and use it for marketing purposes. Once this information is combined it is all considered personal information. Information collected from those who register on our Web site is used to provide registrants the benefits associated with such registration (e.g. subscription to newsletters; access to the latest game news and contests; message boards chat rooms or forums; and product registration.). From time to time we may contact you to ask you for your opinion about certain matters in the form of online polls or surveys including your opinion with respect to our games or other products and services. Your responses to these polls help us provide products and services of interest to you.* Contests and PromotionsFrom time to time Activision may run contests or promotions on our Web site and collect certain personal information in connection with such event. The information may include your name address e-mail address phone number and birth date. This information will be used only for the purpose of your participation in product-specific contests and promotions as well as informing you of upcoming products and services.* Customer ServiceIn order to provide you with the best possible customer service Activision may collect some personal information from you including your name e-mail address and birth date. This information will be used only for the purpose of solving your customer support inquiry and will be saved for twelve (12) months in the event additional customer support requests arise.* Demo Downloads/Mature-Rated ContentVisitors interested in accessing Mature-rated content or downloading demonstration versions of Activision games with an ESRB rating of "M" (Mature) or PEGI 18 may need to provide a valid credit card number and expiration date. Such information will be used only for the purpose of verifying age and will not be stored.* RésumésActivision allows for the online submission of résumés. Personal information collected in association with résumés will be used solely for the purpose of accepting and evaluating candidate submissions for job postings. This information may only be shared within the Activision group if you have given your prior consent or if the respective job relates to another company within the Activision group. Information collected in association with résumés is not subject to the terms of this Online Privacy Statement.*Online ServicesActivision may provide you with a variety of Online Services. Activision may collect non-personal information from you such as scores rankings game play statistics game feature usages and achievements. We may also collect information stored in your account preferences and online profiles including for example your purchases and friends lists. Activision may combine non-personal information w ...
#
# Extracted Summary# 5
# Session data is cleared when a browser is closed.
# Original Paragraph# 5
# Pinkbike does not collect information from not logged in visitors interacting with the site. A cookie and ip address may be tracked to allow technology to better the visitor experience during a session. Session data is cleared when a browser is closed.Visitors may recieve third-party advertising. See point 5

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Preparing the Data

# %%
# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}

# %%
def clean_text(text, remove_stopwords = True):
    '''Remove unwanted characters, stopwords, and format the text to create fewer nulls word embeddings'''
    
    # Convert words to lower case
    text = text.lower()
    
    # Replace shorter contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters if left although we have removed them already while scraping
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %% [markdown]
# We will remove the stopwords from the texts because they do not provide much use for training our model.
# However, we will keep them for our summaries so that they sound more like natural phrases.

# %%
import nltk
nltk.download('stopwords')
  
# Clean the summaries and texts
clean_summaries = []
for summary in headings.Summary:
    clean_summaries.append(clean_text(summary, remove_stopwords=False))
print("Summaries are complete.")

clean_texts = []
for text in headings.Policy:
    clean_texts.append(clean_text(text))
print("Texts are complete.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Summaries are complete.
# Texts are complete.

# %%
# Inspect the cleaned summaries and texts to ensure they have been cleaned well
for i in range(5):
    print("Clean #",i+1)
    print("Extracted Summary",i+1)
    print(clean_summaries[i])
    print("Orignal Paragraph",i+1)
    print(clean_texts[i])
    print()
# Out:
# Clean # 1
# Extracted Summary 1
# if the browser is loading a page and the server requests the information stored in the cookie the cookie is sent back to the server
# Orignal Paragraph 1
# cookies text files sent web servers web browsers stored user computer mobile device browser loading page server requests information stored cookie cookie sent back server cookies contain data user activities website used web servers identify track users navigate different pages website identify users returning website cookies may either persistent session cookies persistent cookie remain valid set expiration date unless deleted user session cookie expire end user session web browser closed
#
# Clean # 2
# Extracted Summary 2
# the weather channel and its affiliateswe use information collected on the services and disclose information to third parties including your physical geographic location to help fulfill your requests or in connection with the operation of the services for example to service your account conduct a transaction or provide a service that you have requested display information and advertisements that we believe match your interests and profile facilitate updates to the services provide support notify you if you ve won a contest or sweepstakes improve the working of the services and compile statistics about our users and your use of the services
# Orignal Paragraph 2
# one valuable assets business except described weather channel rent sell share pii people nonaffiliated companies weather channel affiliateswe use information collected services disclose information third parties including physical geographic location help fulfill requests connection operation services example service account conduct transaction provide service requested display information advertisements believe match interests profile facilitate updates services provide support notify contest sweepstakes improve working services compile statistics users use services third parties may occasion combine information information obtained parties market products services may interest various points may provide opportunity opt receive special offers weather channel affiliates choose opt weather channel affiliates use pii inform products services available weather channel affiliates including wsi corporation weather underground llc weather central lp products may include example schedules special programs weather channel cable network offers purchase calendar weather channel b companies offering promotions products servicesat times provide opportunity opt receive promotions products services third party sponsors permission weather channel periodically send via e mail offers promotions third party sponsors select based upon interests user profile case share information third party sponsors mailing always opportunity opt receiving future offers following unsubscribe link included email instances provide opportunity receive products services directly specifically identified third parties services instances must explicitly consent receive offer explicitly agree receive offers specific third parties information shared specific third party enable provide offer requested responsible information collection practices third parties information provided governed privacy policies third parties review privacy policies parties supplying pii c third party processorswhen information collected services may collected directly shared selected third parties connection operation services provision services third party processors third party processors may include example companies operate online store process credit card information handle shipping weather channel deliver materials via e mail postal service organize administer process provide advertising services analyze data behalf help us provide relevant offers eliminate delivery duplicate offers well correcting updating users data based information provide also provide information third party mapping service providers provide map content services third party processors authorized use information provide carry service providing weather channel require third party processors securely store pii provide maintain accessed needed future purposes third party processors contractually bound us keep personally identifiable information confidential web sites services linkslike many web sites internet internet based services many services link pages located web sites services maintained various entities cases may link pages web sites framed elements services header footer case url identify site visiting cases advertisements connecting another site service click otherwise activate opportunities including click call click text click email opportunities sites services bound privacy policy responsible information collection practices privacy policies organizations may differ example respect level security use cookies collection use disclosure pii services allow users interface sites services including facebook twitter sessionm mpoints remain logged sites services log sites services proceeding interfaces allowing services access information sites services agreeing sites services terms use log sites services content post sites services may also post services use sites services subject privacy policies sites services privacy policy services use third party operating systems platforms communication services devices soft ...
#
# Clean # 3
# Extracted Summary 3
# when you enter sensitive financial information  such as a credit card number  on our order forms we encrypt the transmission of that information using commercially reasonable methods
# Orignal Paragraph 3
# ea understands importance keeping information safe secure ea make commercially reasonable efforts protect personal information ensure security systems enter sensitive financial information credit card number order forms encrypt transmission information using commercially reasonable methods method transmission internet method electronic storage 100 secure however cannot guarantee information accessed disclosed altered destroyed breach physical technical managerial safeguards cannot assume responsibility liability unauthorized access servers systems
#
# Clean # 4
# Extracted Summary 4
# we may also obtain information about you from other sources as far as such other sources are legally entitled to share such information and combine that information with information we have collected from you   web site registrationactivision may collect personal information from you when registering as a web site member including your name address e mail address and phone number
# Orignal Paragraph 4
# activision collects personal information voluntary basis submit personal information activision usually take form 1 web site registration 2 contests promotions 3 customer service 4 demo downloads 5 purchase product service online stores 6 use website online property including online services defined 7 online submission rã©sumã© job openings information collect may include personal information name e mail address phone number home address addition may collect demographic information age gender interests may also obtain information sources far sources legally entitled share information combine information information collected web site registrationactivision may collect personal information registering web site member including name address e mail address phone number may also collect demographic information gender birth date may combine personal information use marketing purposes information combined considered personal information information collected register web site used provide registrants benefits associated registration e g subscription newsletters access latest game news contests message boards chat rooms forums product registration time time may contact ask opinion certain matters form online polls surveys including opinion respect games products services responses polls help us provide products services interest contests promotionsfrom time time activision may run contests promotions web site collect certain personal information connection event information may include name address e mail address phone number birth date information used purpose participation product specific contests promotions well informing upcoming products services customer servicein order provide best possible customer service activision may collect personal information including name e mail address birth date information used purpose solving customer support inquiry saved twelve 12 months event additional customer support requests arise demo downloads mature rated contentvisitors interested accessing mature rated content downloading demonstration versions activision games esrb rating mature pegi 18 may need provide valid credit card number expiration date information used purpose verifying age stored résumésactivision allows online submission résumés personal information collected association résumés used solely purpose accepting evaluating candidate submissions job postings information may shared within activision group given prior consent respective job relates another company within activision group information collected association résumés subject terms online privacy statement online servicesactivision may provide variety online services activision may collect non personal information scores rankings game play statistics game feature usages achievements may also collect information stored account preferences online profiles including example purchases friends lists activision may combine non personal information personal information order tailor advertisements web pages game play experiences online services use certain features online services messages boards profiles contributing user generadquisición de bienes servicios través de nuestra tienda en líneaated content may involve disclosure personal information acknowledge right expectation privacy confidentiality using features online services instances may use third party gaming service provide authentication online services case may asked provide account information associated third party service signing online services addition registering online services directly third party gaming service certain membership information transferred automatically activision register
#
# Clean # 5
# Extracted Summary 5
# session data is cleared when a browser is closed
# Orignal Paragraph 5
# pinkbike collect information logged visitors interacting site cookie ip address may tracked allow technology better visitor experience session session data cleared browser closed visitors may recieve third party advertising see point 5

# %%
def count_words(count_dict, text):
    '''Count the number of occurrences of each word in a set of text'''
    for sentence in text:
        for word in sentence.split():
            if word not in count_dict:
                count_dict[word] = 1
            else:
                count_dict[word] += 1

# %%
# Find the number of times each word was used and the size of the vocabulary
word_counts = {}

count_words(word_counts, clean_summaries)
count_words(word_counts, clean_texts)
            
print("Size of Vocabulary:", len(word_counts))
# Out:
# Size of Vocabulary: 20638

# %% [markdown]
# #Word Embeddings

# %%
# Load Conceptnet Numberbatch's (CN) embeddings, probably better than Glove 
#(https://github.com/commonsense/conceptnet-numberbatch)

embeddings_index = {}
with open('drive/My Drive/Colab Notebooks/numberbatch-en-17.02.txt', encoding='utf-8') as f:
    for line in f:
        #print (line)
        values = line.split(' ')
        #print (values[0])
        word = values[0]
        #print (values[1:])
        embedding = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = embedding

        
print('Word embeddings:', len(embeddings_index))
# Out:
# Word embeddings: 484557

# %%
# Find the number of words that are missing from CN, and are used more than our threshold.
missing_words = 0
threshold = 20    #20threshold #Thrshold is here if any word appear more than 20 therefore
#I use a threshold of 20, so that words not in CN can be added to our word_embedding_matrix, but they need to be common enough in the paragraphs so that the model can understand their meaning.
rey=[]
for word, count in word_counts.items():
    if count > threshold:
        if word not in embeddings_index:
            missing_words += 1
            rey.append(word)
            
missing_ratio = round(missing_words/len(word_counts),4)*100
            
print("Number of words missing from CN:", missing_words)
print("Percent of words that are missing from vocabulary: {}%".format(missing_ratio))
print(rey)
# Out:
# Number of words missing from CN: 122
# Percent of words that are missing from vocabulary: 0.59%
# ['cookieswe', 'auap', '10', '30', '800', '13', '“how', 'realgm', '“contact', 'us”', 'cricbuzz', '—', '22', 'mixedmartialarts', '–', '12', 'borderfree', 'malayala', '•', 'informationwhen', '”', '100', '9gag', 'rewards®', '“web', '18', '888', 'vegasinsider', 'sulekha', 'bcrs', 'doccheck', 'soundcloud®', 'mansueto', 'informationwe', 'techmedia', 'information”', '44', 'supermedia', 'pegym', 'out”', 'cookies”', 'mouthshut', '1798', 'myfitnesspal', 'footytube', '90', 'interpals', '·', 'b92', 'implix', 'bitly', 'mapsofindia', 'bitpay', 'italki', 'lumosity', '“we”', '“us”', 'mobile9', 'uclick', '24', 'intermarkets', '1998', 'researchgate', '2011', 'roblox', '15', '2000', 'andto', 'domaintools', 'linguee', 'viumbe', '83', 'netdoctor', '17', 'zedo', '192', 'informationin', '128', 'surfline', '“cookies”', 'lyricsfreak', '866', 'pinterest', 'teenshealth', 'sourceswe', 'yardbarker', 'mediaplex', '2012', 'lsos', 'aboutads', '“personal', 'data”', '“opt', 'bibsonomy', '20', '\uf0b7', 'gearslutz', 'plasmanet', 'zomato', '21', 'informationif', '2003', '11', '00', 'christianpost', 'networkadvertising', 'third–party', '2013', 'codecademy', 'mappy', 'web18', 'coursera', 'udacity', 'vg247', 'retailmenot', '14', '101', '16', '“help”', 'ahfc', '“cookie”', 'mileageplus']

# %%
# Limit the vocab that we will use to words that appear more than  threshold 

#dictionary to convert words to integers
vocab_to_int = {} 

value = 0
for word, count in word_counts.items():
    if count >= threshold or word in embeddings_index:
        vocab_to_int[word] = value
        value += 1

# Special tokens that will be added to our vocab
codes = ["<UNK>","<PAD>","<EOS>","<GO>"]   

# Add codes to vocab
for code in codes:
    vocab_to_int[code] = len(vocab_to_int)

# Dictionary to convert integers to words
int_to_vocab = {}
for word, value in vocab_to_int.items():
    int_to_vocab[value] = word

usage_ratio = round(len(vocab_to_int) / len(word_counts),4)*100

print("Total number of unique words:", len(word_counts))
print("Number of words we will use:", len(vocab_to_int))
print("Percent of words we will use: {}%".format(usage_ratio))
# Out:
# Total number of unique words: 20638
# Number of words we will use: 11684
# Percent of words we will use: 56.61000000000001%

# %%
# Need to use 300 for embedding dimensions to match CN's vectors.
embedding_dim = 300
nb_words = len(vocab_to_int)

# Create matrix with default values of zero
word_embedding_matrix = np.zeros((nb_words, embedding_dim), dtype=np.float32)
for word, i in vocab_to_int.items():
    if word in embeddings_index:
        word_embedding_matrix[i] = embeddings_index[word]
    else:
        # If word not in CN, create a random embedding for it
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        print (new_embedding)
        embeddings_index[word] = new_embedding
        word_embedding_matrix[i] = new_embedding 

# Check if value matches len(vocab_to_int)
print(len(word_embedding_matrix))
# Out:
# [ 9.38552393e-01 -1.26789851e-01  2.18896366e-02  6.17978394e-01
#  -1.85553445e-01  6.45900714e-01 -4.25754861e-01 -7.38292947e-01
#   1.73234476e-01  7.09489351e-01  7.51146155e-01 -5.23828666e-01
#  -7.71412400e-02  5.28138758e-01 -5.41541849e-02  9.11013350e-01
#  -4.51455847e-01 -5.34323708e-01 -8.33437394e-01 -6.89330756e-01
#  -3.31888971e-01  1.55914086e-01 -3.89707104e-01 -4.80716887e-01
#   9.28899503e-01 -6.47938230e-01  6.19603407e-01  3.18771968e-01
#  -3.29277506e-02  5.41170976e-01  6.82016772e-01  9.63586382e-01
#  -3.63044489e-01 -1.10587878e-01  6.36955077e-01 -8.86233305e-01
#  -9.58324372e-01 -9.64608836e-01 -1.48594308e-01 -7.30174177e-01
#   8.89473995e-01  4.52163120e-01 -3.57320996e-01  1.44031604e-01
#   6.78991074e-01  1.13691946e-01  3.56625491e-01 -9.08695716e-01
#  -4.02359622e-01  3.39131441e-01  9.64308130e-02 -1.80134714e-01
#  -5.31435587e-01  4.35433941e-01 -5.91769204e-01  1.63048725e-01
#  -9.10561986e-01 -4.79355657e-01 -7.63951163e-01 -6.46521353e-01
#  -3.35027447e-01  7.56180257e-01 -6.36115306e-01 -6.23334832e-02
#   5.85516826e-01 -2.60366594e-01  6.84064916e-02  9.79978767e-01
#  -9.11150780e-01  4.58906842e-01 -4.03856198e-02  4.47956106e-01
#   9.77980649e-01  8.96957726e-01  9.76010709e-01  7.97538613e-01
#  -7.39471664e-01 -5.09033561e-01 -2.29212691e-01  6.98743336e-01
#  -2.81065562e-02 -4.21028202e-01 -1.45486206e-02  2.84466043e-01
#  -2.33074873e-01 -4.31151075e-02 -4.71692950e-01 -9.44223917e-02
#   1.49543296e-01  3.03736596e-01 -4.03499966e-01  5.92625952e-02
#   7.45397576e-01  2.84169312e-01  5.13547895e-01 -6.11714262e-01
#  -1.19727753e-01  1.77642059e-01  6.55227357e-01  3.38655941e-01
#   1.72603541e-01 -8.33093077e-01 -4.90995223e-01 -9.14159858e-01
#   1.11406231e-01 -3.17756182e-01  7.21362412e-01  9.76878329e-01
#   9.25733455e-01  6.90098611e-01 -3.65091373e-01  5.20209552e-02
#   1.10428714e-01  7.51120094e-01  4.33891289e-01 -1.10486585e-01
#   8.59047966e-02 -4.38256508e-01 -1.49513546e-01 -5.92038824e-01
#  -8.26644508e-01 -7.53369294e-01  7.39117323e-01  4.83465477e-01
#  -2.62216707e-01  4.85878370e-01  8.95664742e-01  7.08782060e-01
#   2.21955555e-01  2.50690380e-01 -5.34522749e-04  1.84681616e-01
#   4.67399239e-01  7.31977572e-02 -5.65649158e-01  6.91386580e-01
#   3.60109874e-01 -5.83238736e-01  9.57463367e-01 -5.40710716e-01
#  -3.74653089e-01  5.43989861e-01  8.41341731e-01 -2.60699391e-01
#   6.92174014e-01 -7.00066348e-01 -2.11263925e-01 -7.55777234e-02
#   6.82153381e-01  6.11828519e-01 -4.34245356e-01 -3.22140136e-01
#  -3.69448821e-01  9.01990635e-01  1.35758321e-01  9.46893060e-01
#  -9.78899956e-01  1.42802301e-01 -2.64201661e-01  6.49164054e-01
#   3.91008575e-01 -5.14318637e-01 -9.59298683e-01  7.11743460e-01
#  -6.86459763e-01 -7.32280337e-01  4.33744058e-01  2.52640992e-02
#   5.82013802e-01 -7.88445165e-01  7.30668946e-01 -6.66762621e-02
#  -1.16796159e-01 -8.67972482e-01  1.24493942e-01  9.61710916e-01
#  -8.89190919e-01 -9.97041656e-01  9.16370328e-01  9.41137847e-01
#   2.76136613e-01  7.88880522e-01  6.28272699e-01  4.35359429e-01
#   8.09692125e-02  3.05582713e-01 -8.10244057e-01  9.34735901e-01]
# 11684

# %%
def convert_to_ints(text, word_count, unk_count, eos=False):
    #'''Convert words in text to an integer.If word is not in vocab_to_int, use UNK's integer.Total the number of words and UNKs.Add EOS token to the end of texts'''
    ints = []
    for sentence in text:
        sentence_ints = []
        for word in sentence.split():
            word_count += 1
            if word in vocab_to_int:
                sentence_ints.append(vocab_to_int[word])
            else:
                sentence_ints.append(vocab_to_int["<UNK>"])
                unk_count += 1
        if eos:
            sentence_ints.append(vocab_to_int["<EOS>"])
        ints.append(sentence_ints)
    return ints, word_count, unk_count

# %%
# Apply convert_to_ints to clean_summaries and clean_texts
word_count = 0
unk_count = 0

int_summaries, word_count, unk_count = convert_to_ints(clean_summaries, word_count, unk_count)
int_texts, word_count, unk_count = convert_to_ints(clean_texts, word_count, unk_count, eos=True)

unk_percent = round(unk_count/word_count,4)*100
# Out:
# Total number of words in Vocab: 1076211
# Total number of UNKs in Vocab: 16320
# Percent of words that are UNK: 1.52%

# %%
print("Total number of words in Vocab:", word_count)
print("Total number of UNKs in Vocab:", unk_count)
print("Percent of words that are UNK: {}%".format(unk_percent))

# %%
#print (int_to_vocab[value] for value in int_summaries[:5])
for value in int_summaries[2:]:
  for value2 in value:
, 499, 23, 3555, 749, 2275, 1355, 89, 276, 424, 101, 499, 5414, 2611, 23, 6028, 1139, 572, 1703, 290, 102, 205, 1355, 51, 1942, 1906, 102, 41, 311, 204, 6012, 3618, 27, 311, 763, 311, 1385, 311, 203, 3618, 499, 23, 848, 133, 134, 177, 10, 303, 253, 133, 840, 259, 89, 2625, 40, 1251, 1121, 460, 20, 277, 303, 20, 560, 2538, 23, 703, 71, 884, 499, 23, 27, 508, 802, 11680, 11680, 420, 1999, 499, 23, 1070, 499, 23, 2162, 4612, 2714, 23, 227, 10, 499, 23, 4635, 499, 23, 849, 20, 1070, 499, 23, 269, 266, 499, 23, 89, 90, 266, 23, 20, 499, 23, 1403, 133, 840, 499, 23, 133, 134, 23, 20, 25, 122, 654, 474, 2889, 721, 23, 2914, 466, 2611, 869, 533, 654, 474, 1865, 23, 869, 111, 5078, 2914, 23, 211, 25, 122, 3138, 533, 6029, 533, 2186, 1733, 2186, 721, 23, 17, 18, 570, 25, 122, 2275, 126, 23, 89, 103, 20, 151, 2315, 24, 10, 40, 25, 122, 2611, 89, 1369, 10, 23, 27, 383, 792, 6030, 585, 158, 23, 17, 18, 570, 2095, 113, 1838, 253, 432, 1044, 133, 618, 849, 20, 1227, 1209, 109, 20, 186, 759, 447, 277, 101, 755, 3502, 798, 2028, 10, 1085, 11680, 17, 18, 25, 122, 1167, 1587, 643, 20, 749, 180, 797, 32, 186, 583, 162, 23, 891, 159, 1767, 486, 10, 51, 342, 1298, 2669, 6031, 180, 797, 462, 759, 447, 449, 1941, 157, 426, 6032, 1042, 6033, 10, 1945, 180, 277, 531, 2222, 532, 1577, 23, 2222, 533, 755, 3502, 798, 2028, 2222, 799, 3738, 11680, 584, 470, 2, 2222, 533, 10, 17, 18, 818, 413, 797, 238, 239, 89, 1468, 10, 17, 18, 117, 797, 238, 239, 3537, 464, 45, 1766, 23, 415, 293, 1767, 583, 23, 162, 542, 549, 51, 41, 162, 892, 395, 32, 4652, 975, 1313, 1985, 228, 891, 1069, 159, 1767, 57, 227, 20, 23, 979, 892, 570, 542, 51, 23, 4214, 71, 1316, 278, 263, 23, 539, 891, 32, 747, 549, 395, 550, 23, 442, 89, 99, 814, 10, 31, 113, 759, 108, 1063, 157, 159, 68, 23, 800, 10, 1540, 25, 26, 40, 89, 99, 759, 108, 4109, 796, 533, 2039, 1151, 1172, 1874, 1152, 454, ...
# 4904

# %%
def create_lengths(text):
    #Create a data frame of the sentence lengths from a text
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

# %%
lengths_summaries = create_lengths(int_summaries)
lengths_texts = create_lengths(int_texts)

print("Extracted Summaries:")
print(lengths_summaries.describe())
print()
print("Paragraphs:")
print(lengths_texts.describe())
# Out:
# Extracted Summaries:
#             counts
# count  4904.000000
# mean     44.424551
# std      34.802341
# min       0.000000
# 25%      21.000000
# 50%      35.000000
# 75%      58.000000
# max     406.000000
#
# Paragraphs:
#             counts
# count  4904.000000
# mean    176.031199
# std     179.663526
# min       1.000000
# 25%      75.000000
# 50%     117.000000
# 75%     209.000000
# max    2370.000000

# %%
print (lengths_summaries[:5])
# Out:
#    counts
# 0      25
# 1     101
# 2      27
# 3      60
# 4       9

# %%
# Inspect the length of texts
#print(lengths_texts,count)

print(np.percentile(lengths_texts.counts, 90))
print(np.percentile(lengths_texts.counts, 95))
print(np.percentile(lengths_texts.counts, 99))
# Out:
# 361.0
# 494.84999999999945
# 941.9100000000008

# %%
# Inspect the length of summaries
print(np.percentile(lengths_summaries.counts, 90))
print(np.percentile(lengths_summaries.counts, 95))
print(np.percentile(lengths_summaries.counts, 99))
# Out:
# 85.0
# 108.0
# 172.0

# %%
def unk_counter(sentence):
    #Counts the number of time UNK appears in a sentence.
    unk_count = 0
    for word in sentence:
        if word == vocab_to_int["<UNK>"]:
            unk_count += 1
    return unk_count

# %%
# Sort the summaries and texts by the length of the texts, shortest to longest
# Limit the length of summaries and texts based on the min and max ranges.
# Remove summaries that include too many UNKs

sorted_summaries = []
sorted_texts = []
max_text_length = 2000
max_summary_length = 500
min_length = 2
unk_text_limit = 1
unk_summary_limit = 0

for length in range(min(lengths_texts.counts), max_text_length): 
    for count, words in enumerate(int_summaries):
        if (len(int_summaries[count]) >= min_length and
            len(int_summaries[count]) <= max_summary_length and
            len(int_texts[count]) >= min_length and
            unk_counter(int_summaries[count]) <= unk_summary_limit and
            unk_counter(int_texts[count]) <= unk_text_limit and
            length == len(int_texts[count])
           ):
            sorted_summaries.append(int_summaries[count])
            sorted_texts.append(int_texts[count])
        
# Compare lengths to ensure they match
print(len(sorted_summaries))
print(len(sorted_texts))
# Out:
# 2841
# 2841

# %% [markdown]
# ## Model Build

# %%
def model_inputs():
    #Create palceholders for inputs to the model
    
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    summary_length = tf.placeholder(tf.int32, (None,), name='summary_length')
    max_summary_length = tf.reduce_max(summary_length, name='max_dec_len')
    text_length = tf.placeholder(tf.int32, (None,), name='text_length')

    return input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length

# %%
def process_encoding_input(target_data, vocab_to_int, batch_size):
    #Remove the last word id from each batch and concat the <GO> to the begining of each batch
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], vocab_to_int['<GO>']), ending], 1)

    return dec_input

# %%
def encoding_layer(rnn_size, sequence_length, num_layers, rnn_inputs, keep_prob):
    #Create the encoding layer
    
    for layer in range(num_layers):
        with tf.variable_scope('encoder_{}'.format(layer)):
            cell_fw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_fw = tf.contrib.rnn.DropoutWrapper(cell_fw, 
                                                    input_keep_prob = keep_prob)

            cell_bw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_bw = tf.contrib.rnn.DropoutWrapper(cell_bw, 
                                                    input_keep_prob = keep_prob)

            enc_output, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw, 
                                                                    cell_bw, 
                                                                    rnn_inputs,
                                                                    sequence_length,
                                                                    dtype=tf.float32)
    # Join outputs since we are using a bidirectional RNN
    enc_output = tf.concat(enc_output,2)
    
    return enc_output, enc_state

# %%
def training_decoding_layer(dec_embed_input, summary_length, dec_cell, initial_state, output_layer, 
                            vocab_size, max_summary_length):
    #Create the training logits
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=summary_length,
                                                        time_major=False)

    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       initial_state,
                                                       output_layer) 

    training_logits, _ , _ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                           output_time_major=False,
                                                           impute_finished=True,
                                                           maximum_iterations=max_summary_length)
    return training_decoder

# %%
def inference_decoding_layer(embeddings, start_token, end_token, dec_cell, initial_state, output_layer,
                             max_summary_length, batch_size):
    #Create the inference logits
    
    start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [batch_size], name='start_tokens')
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embeddings,
                                                                start_tokens,
                                                                end_token)
                
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        initial_state,
                                                        output_layer)
                
    inference_logits, _ , _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            output_time_major=False,
                                                            impute_finished=True,
                                                            maximum_iterations=max_summary_length)
    
    return inference_decoder

# %%
def decoding_layer(dec_embed_input, embeddings, enc_output, enc_state, vocab_size, text_length, summary_length, 
                   max_summary_length, rnn_size, vocab_to_int, keep_prob, batch_size, num_layers):
    #Create the decoding cell and attention for the training and inference decoding layers
    
    for layer in range(num_layers):
        with tf.variable_scope('decoder_{}'.format(layer)):
            lstm = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            dec_cell = tf.contrib.rnn.DropoutWrapper(lstm, 
                                                     input_keep_prob = keep_prob)
    
    output_layer = Dense(vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    attn_mech = tf.contrib.seq2seq.BahdanauAttention(rnn_size,
                                                  enc_output,
                                                  text_length,
                                                  normalize=False,
                                                  name='BahdanauAttention')

    dec_cell = tf.contrib.seq2seq.AttentionWrapper(dec_cell,
                                                          attn_mech,
                                                          rnn_size)
            
    #initial_state = tf.contrib.seq2seq.AttentionWrapperState(enc_state[0],
    #                                                                _zero_state_tensors(rnn_size, 
    #                                                                                    batch_size, 
    #                                                                                    tf.float32)) 
    initial_state = dec_cell.zero_state(batch_size=batch_size,dtype=tf.float32).clone(cell_state=enc_state[0])

    with tf.variable_scope("decode"):
        training_decoder = training_decoding_layer(dec_embed_input, 
                                                  summary_length, 
                                                  dec_cell, 
                                                  initial_state,
                                                  output_layer,
                                                  vocab_size, 
                                                  max_summary_length)
        
        training_logits,_ ,_ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                  output_time_major=False,
                                  impute_finished=True,
                                  maximum_iterations=max_summary_length)
    with tf.variable_scope("decode", reuse=True):
        inference_decoder = inference_decoding_layer(embeddings,  
                                                    vocab_to_int['<GO>'], 
                                                    vocab_to_int['<EOS>'],
                                                    dec_cell, 
                                                    initial_state, 
                                                    output_layer,
                                                    max_summary_length,
                                                    batch_size)
        
        inference_logits,_ ,_ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                  output_time_major=False,
                                  impute_finished=True,
                                  maximum_iterations=max_summary_length)

    return training_logits, inference_logits

# %%
def seq2seq_model(input_data, target_data, keep_prob, text_length, summary_length, max_summary_length, 
                  vocab_size, rnn_size, num_layers, vocab_to_int, batch_size):
    #Use the previous functions to create the training and inference logits
    
    # Use Numberbatch's embeddings and the newly created ones as our embeddings
    embeddings = word_embedding_matrix
    
    enc_embed_input = tf.nn.embedding_lookup(embeddings, input_data)
    enc_output, enc_state = encoding_layer(rnn_size, text_length, num_layers, enc_embed_input, keep_prob)
    
    dec_input = process_encoding_input(target_data, vocab_to_int, batch_size)
    dec_embed_input = tf.nn.embedding_lookup(embeddings, dec_input)
    
    training_logits, inference_logits  = decoding_layer(dec_embed_input, 
                                                        embeddings,
                                                        enc_output,
                                                        enc_state, 
                                                        vocab_size, 
                                                        text_length, 
                                                        summary_length, 
                                                        max_summary_length,
                                                        rnn_size, 
                                                        vocab_to_int, 
                                                        keep_prob, 
                                                        batch_size,
                                                        num_layers)
    
    return training_logits, inference_logits

# %%
def pad_sentence_batch(sentence_batch):
    #Pad sentences with <PAD> so that each sentence of a batch has the same length
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [vocab_to_int['<PAD>']] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def get_batches(summaries, texts, batch_size):
    #Batch summaries, texts, and the lengths of their sentences together
    for batch_i in range(0, len(texts)//batch_size):
        start_i = batch_i * batch_size
        summaries_batch = summaries[start_i:start_i + batch_size]
        texts_batch = texts[start_i:start_i + batch_size]
        pad_summaries_batch = np.array(pad_sentence_batch(summaries_batch))
        pad_texts_batch = np.array(pad_sentence_batch(texts_batch))
        
        # Need the lengths for the _lengths parameters
        pad_summaries_lengths = []
        for summary in pad_summaries_batch:
            pad_summaries_lengths.append(len(summary))
        
        pad_texts_lengths = []
        for text in pad_texts_batch:
            pad_texts_lengths.append(len(text))
        
        yield pad_summaries_batch, pad_texts_batch, pad_summaries_lengths, pad_texts_lengths

# %%
# Hyperparameters
epochs = 100
batch_size = 32
rnn_size = 256
num_layers = 2
learning_rate = 0.005
keep_probability = 0.75

# %%
# Build the graph
train_graph = tf.Graph()
# Set the graph to default to ensure that it is ready for training
with train_graph.as_default():
    
    # Load the model inputs    
    input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length = model_inputs()

    # Create the training and inference logits
    training_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                      targets, 
                                                      keep_prob,   
                                                      text_length,
                                                      summary_length,
                                                      max_summary_length,
                                                      len(vocab_to_int)+1,
                                                      rnn_size, 
                                                      num_layers, 
                                                      vocab_to_int,
                                                      batch_size)
    
    # Create tensors for the training logits and inference logits
    training_logits = tf.identity(training_logits.rnn_output, 'logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')
    
    # Create the weights for sequence_loss
    masks = tf.sequence_mask(summary_length, max_summary_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
print("Graph is built.")
# Out:
# Graph is built.

# %% [markdown]
# ## Training Model

# %%
# Subset the data for training
start = 00000
end = start + 9600
sorted_summaries_short = sorted_summaries
sorted_texts_short = sorted_texts
#print(sorted_summaries)
print("The shortest text length:", len(sorted_texts_short[0]))
print("The longest text length:",len(sorted_texts_short[-1]))
# Out:
# The shortest text length: 3
# The longest text length: 920

# %%
# Train the Model
learning_rate_decay = 0.4
min_learning_rate = 0.0005
display_step = 20 # Check training loss after every 20 batches
stop_early = 0 
stop = 6000000000000000 #3 # If the update loss does not decrease in 3 consecutive update checks, stop training
per_epoch = 3 # Make 3 update checks per epoch
update_check = (len(sorted_texts_short)//batch_size//per_epoch)-1

update_loss = 0 
batch_loss = 0
summary_update_loss = [] # Record the update losses for saving improvements in the model

  
tf.reset_default_graph()
checkpoint = "drive/My Drive/Colab Notebooks/best_model.ckpt"  #300k sentence
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    
    # If we want to continue training a previous session
    # loader = tf.train.import_meta_graph(checkpoint + '.meta')
    # loader.restore(sess, checkpoint)
    #sess.run(tf.local_variables_initializer())

    for epoch_i in range(1, epochs+1):
        update_loss = 0
        batch_loss = 0
        for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
                get_batches(sorted_summaries_short, sorted_texts_short, batch_size)):
            start_time = time.time()
            _, loss = sess.run(
                [train_op, cost],
                {input_data: texts_batch,
                 targets: summaries_batch,
                 lr: learning_rate,
                 summary_length: summaries_lengths,
                 text_length: texts_lengths,
                 keep_prob: keep_probability})

            batch_loss += loss
            update_loss += loss
            end_time = time.time()
            batch_time = end_time - start_time

            if batch_i % display_step == 0 and batch_i > 0:
                print('Epoch {:>3}/{} Batch {:>4}/{} - Loss: {:>6.3f}, Seconds: {:>4.2f}'
                      .format(epoch_i,
                              epochs, 
                              batch_i, 
                              len(sorted_texts_short) // batch_size, 
                              batch_loss / display_step, 
                              batch_time*display_step))
                batch_loss = 0
                
                #saver = tf.train.Saver() 
                #saver.save(sess, checkpoint)
                
            if batch_i % update_check == 0 and batch_i > 0:
                print("Average loss for this update:", round(update_loss/update_check,3))
                summary_update_loss.append(update_loss)
                
              
                  
                # If the update loss is at a new minimum, save the model
                if update_loss <= min(summary_update_loss):
                    print('New Record!') 
                    stop_early = 0
                    saver = tf.train.Saver() 
                    saver.save(sess, checkpoint)

                else:
                    print("No Improvement.")
                    #stop_early += 1
                    #if stop_early == stop:
                    #    break
                update_loss = 0
            
                    
        # Reduce learning rate, but not below its minimum value
        learning_rate *= learning_rate_decay
        if learning_rate < min_learning_rate:
            learning_rate = min_learning_rate
        
        #if stop_early == stop:
        #    print("Stopping Training.")
            #break
# Out:
# Epoch   1/100 Batch   20/88 - Loss:  3.484, Seconds: 6.22
# Average loss for this update: 3.289
# New Record!
# Epoch   1/100 Batch   40/88 - Loss:  2.639, Seconds: 10.43
# Average loss for this update: 2.585
# New Record!
# Epoch   1/100 Batch   60/88 - Loss:  2.683, Seconds: 16.57
# Epoch   1/100 Batch   80/88 - Loss:  2.319, Seconds: 25.75
# Average loss for this update: 2.34
# New Record!
# Epoch   2/100 Batch   20/88 - Loss:  2.502, Seconds: 5.73
# Average loss for this update: 2.536
# No Improvement.
# Epoch   2/100 Batch   40/88 - Loss:  2.495, Seconds: 9.49
# Average loss for this update: 2.454
# No Improvement.
# Epoch   2/100 Batch   60/88 - Loss:  2.539, Seconds: 16.81
# Epoch   2/100 Batch   80/88 - Loss:  2.182, Seconds: 25.60
# Average loss for this update: 2.201
# New Record!
# Epoch   3/100 Batch   20/88 - Loss:  2.344, Seconds: 5.71
# Average loss for this update: 2.373
# No Improvement.
# Epoch   3/100 Batch   40/88 - Loss:  2.318, Seconds: 9.10
# Average loss for this update: 2.288
# No Improvement.
# Epoch   3/100 Batch   60/88 - Loss:  2.377, Seconds: 16.32
# Epoch   3/100 Batch   80/88 - Loss:  2.042, Seconds: 25.44
# Average loss for this update: 2.06
# New Record!
# Epoch   4/100 Batch   20/88 - Loss:  2.196, Seconds: 6.29
# Average loss for this update: 2.222
# No Improvement.
# Epoch   4/100 Batch   40/88 - Loss:  2.184, Seconds: 9.48
# Average loss for this update: 2.17
# No Improvement.
# Epoch   4/100 Batch   60/88 - Loss:  2.262, Seconds: 17.77
# Epoch   4/100 Batch   80/88 - Loss:  1.964, Seconds: 24.72
# Average loss for this update: 1.981
# New Record!
# Epoch   5/100 Batch   20/88 - Loss:  2.076, Seconds: 6.91
# Average loss for this update: 2.107
# No Improvement.
# Epoch   5/100 Batch   40/88 - Loss:  2.084, Seconds: 9.07
# Average loss for this update: 2.076
# No Improvement.
# Epoch   5/100 Batch   60/88 - Loss:  2.170, Seconds: 16.15
# Epoch   5/100 Batch   80/88 - Loss:  1.896, Seconds: 27.52
# Average loss for this update: 1.911
# New Record!
# Epoch   6/100 Batch   20/88 - Loss:  1.965, Seconds: 6.74
# Average loss for this update: 1.995
# No Improvement.
# Epoch   6/100 Batch   40/88 - Loss:  1.984, Seconds: 10.80
# Average loss for this update: 1.99
# No Improvement.
# Epoch   6/100 Batch   60/88 - Loss:  2.084, Seconds: 16.99
# Epoch   6/100 Batch   80/88 - Loss:  1.837, Seconds: 26.89
# Average loss for this update: 1.848
# New Record!
# Epoch   7/100 Batch   20/88 - Loss:  1.864, Seconds: 6.51
# Average loss for this update: 1.891
# No Improvement.
# Epoch   7/100 Batch   40/88 - Loss:  1.892, Seconds: 9.17
# Average loss for this update: 1.916
# No Improvement.
# Epoch   7/100 Batch   60/88 - Loss:  2.010, Seconds: 17.38
# Epoch   7/100 Batch   80/88 - Loss:  1.786, Seconds: 24.81
# Average loss for this update: 1.794
# New Record!
# Epoch   8/100 Batch   20/88 - Loss:  1.784, Seconds: 6.54
# Average loss for this update: 1.811
# No Improvement.
# Epoch   8/100 Batch   40/88 - Loss:  1.827, Seconds: 9.12
# Average loss for this update: 1.851
# No Improvement.
# Epoch   8/100 Batch   60/88 - Loss:  1.938, Seconds: 16.72
# Epoch   8/100 Batch   80/88 - Loss:  1.735, Seconds: 26.32
# Epoch  16/100 Batch   20/88 - Loss:  1.160, Seconds: 6.14
# Average loss for this update: 1.181
# New Record!
# Epoch  16/100 Batch   40/88 - Loss:  1.267, Seconds: 10.72
# Average loss for this update: 1.362
# No Improvement.
# Epoch  16/100 Batch   60/88 - Loss:  1.453, Seconds: 19.48
# Epoch  16/100 Batch   80/88 - Loss:  1.428, Seconds: 25.48
# Average loss for this update: 1.42
# No Improvement.
# Epoch  17/100 Batch   20/88 - Loss:  1.110, Seconds: 5.69
# Average loss for this update: 1.132
# New Record!
# Epoch  17/100 Batch   40/88 - Loss:  1.226, Seconds: 9.21
# Average loss for this update: 1.333
# No Improvement.
# Epoch  17/100 Batch   60/88 - Loss:  1.430, Seconds: 17.67
# Epoch  17/100 Batch   80/88 - Loss:  1.404, Seconds: 24.04
# Average loss for this update: 1.398
# No Improvement.
# Epoch  18/100 Batch   20/88 - Loss:  1.065, Seconds: 6.34
# Average loss for this update: 1.087
# New Record!
# Epoch  18/100 Batch   40/88 - Loss:  1.184, Seconds: 10.41
# Average loss for this update: 1.295
# No Improvement.
# Epoch  18/100 Batch   60/88 - Loss:  1.390, Seconds: 17.98
# Epoch  18/100 Batch   80/88 - Loss:  1.377, Seconds: 27.24
# Average loss for this update: 1.368
# No Improvement.
# Epoch  19/100 Batch   20/88 - Loss:  1.027, Seconds: 5.78
# Average loss for this update: 1.045
# New Record!
# Epoch  19/100 Batch   40/88 - Loss:  1.138, Seconds: 9.27
# Average loss for this update: 1.252
# No Improvement.
# Epoch  19/100 Batch   60/88 - Loss:  1.350, Seconds: 16.90
# Epoch  19/100 Batch   80/88 - Loss:  1.347, Seconds: 26.09
# Average loss for this update: 1.339
# No Improvement.
# Epoch  20/100 Batch   20/88 - Loss:  0.980, Seconds: 6.61
# Average loss for this update: 0.998
# New Record!
# Epoch  20/100 Batch   40/88 - Loss:  1.092, Seconds: 9.17
# Average loss for this update: 1.208
# No Improvement.
# Epoch  20/100 Batch   60/88 - Loss:  1.309, Seconds: 17.28
# Epoch  20/100 Batch   80/88 - Loss:  1.329, Seconds: 27.03
# Average loss for this update: 1.319
# No Improvement.
# Epoch  21/100 Batch   20/88 - Loss:  0.936, Seconds: 6.86
# Average loss for this update: 0.955
# New Record!
# Epoch  21/100 Batch   40/88 - Loss:  1.050, Seconds: 9.31
# Average loss for this update: 1.175
# No Improvement.
# Epoch  21/100 Batch   60/88 - Loss:  1.279, Seconds: 17.74
# Epoch  21/100 Batch   80/88 - Loss:  1.305, Seconds: 24.10
# Average loss for this update: 1.295
# No Improvement.
# Epoch  22/100 Batch   20/88 - Loss:  0.909, Seconds: 5.91
# Average loss for this update: 0.923
# New Record!
# Epoch  22/100 Batch   40/88 - Loss:  1.009, Seconds: 10.07
# Average loss for this update: 1.138
# No Improvement.
# Epoch  22/100 Batch   60/88 - Loss:  1.245, Seconds: 18.03
# Epoch  22/100 Batch   80/88 - Loss:  1.288, Seconds: 24.40
# Average loss for this update: 1.277
# No Improvement.
# Epoch  23/100 Batch   20/88 - Loss:  0.877, Seconds: 5.75
# Epoch  37/100 Batch   40/88 - Loss:  0.631, Seconds: 9.13
# Average loss for this update: 0.761
# No Improvement.
# Epoch  37/100 Batch   60/88 - Loss:  0.865, Seconds: 19.40
# Epoch  37/100 Batch   80/88 - Loss:  1.016, Seconds: 25.71
# Average loss for this update: 1.0
# No Improvement.
# Epoch  38/100 Batch   20/88 - Loss:  0.531, Seconds: 5.63
# Average loss for this update: 0.539
# New Record!
# Epoch  38/100 Batch   40/88 - Loss:  0.604, Seconds: 9.01
# Average loss for this update: 0.74
# No Improvement.
# Epoch  38/100 Batch   60/88 - Loss:  0.849, Seconds: 17.91
# Epoch  38/100 Batch   80/88 - Loss:  0.997, Seconds: 25.54
# Average loss for this update: 0.984
# No Improvement.
# Epoch  39/100 Batch   20/88 - Loss:  0.519, Seconds: 6.48
# Average loss for this update: 0.529
# New Record!
# Epoch  39/100 Batch   40/88 - Loss:  0.600, Seconds: 10.11
# Average loss for this update: 0.726
# No Improvement.
# Epoch  39/100 Batch   60/88 - Loss:  0.833, Seconds: 16.93
# Epoch  39/100 Batch   80/88 - Loss:  0.988, Seconds: 24.64
# Average loss for this update: 0.976
# No Improvement.
# Epoch  40/100 Batch   20/88 - Loss:  0.503, Seconds: 5.82
# Average loss for this update: 0.511
# New Record!
# Epoch  40/100 Batch   40/88 - Loss:  0.576, Seconds: 9.23
# Average loss for this update: 0.706
# No Improvement.
# Epoch  40/100 Batch   60/88 - Loss:  0.812, Seconds: 16.85
# Epoch  40/100 Batch   80/88 - Loss:  0.967, Seconds: 24.17
# Average loss for this update: 0.954
# No Improvement.
# Epoch  41/100 Batch   20/88 - Loss:  0.484, Seconds: 6.06
# Average loss for this update: 0.497
# New Record!
# Epoch  41/100 Batch   40/88 - Loss:  0.562, Seconds: 10.18
# Average loss for this update: 0.683
# No Improvement.
# Epoch  41/100 Batch   60/88 - Loss:  0.787, Seconds: 17.32
# Epoch  41/100 Batch   80/88 - Loss:  0.952, Seconds: 26.42
# Average loss for this update: 0.94
# No Improvement.
# Epoch  42/100 Batch   20/88 - Loss:  0.471, Seconds: 6.31
# Average loss for this update: 0.481
# New Record!
# Epoch  42/100 Batch   40/88 - Loss:  0.544, Seconds: 10.32
# Average loss for this update: 0.663
# No Improvement.
# Epoch  42/100 Batch   60/88 - Loss:  0.763, Seconds: 18.85
# Epoch  42/100 Batch   80/88 - Loss:  0.933, Seconds: 25.61
# Average loss for this update: 0.921
# No Improvement.
# Epoch  43/100 Batch   20/88 - Loss:  0.455, Seconds: 6.20
# Average loss for this update: 0.465
# New Record!
# Epoch  43/100 Batch   40/88 - Loss:  0.534, Seconds: 9.37
# Average loss for this update: 0.651
# No Improvement.
# Epoch  43/100 Batch   60/88 - Loss:  0.750, Seconds: 17.64
# Epoch  43/100 Batch   80/88 - Loss:  0.925, Seconds: 26.12
# Average loss for this update: 0.911
# No Improvement.
# Epoch  44/100 Batch   20/88 - Loss:  0.442, Seconds: 5.74
# Average loss for this update: 0.452
# New Record!
# Epoch  44/100 Batch   40/88 - Loss:  0.515, Seconds: 9.00
# Average loss for this update: 0.635
# No Improvement.
# Epoch  44/100 Batch   60/88 - Loss:  0.736, Seconds: 18.32
# Epoch  44/100 Batch   80/88 - Loss:  0.914, Seconds: 24.47
# Average loss for this update: 0.901
# No Improvement.
# Epoch  45/100 Batch   20/88 - Loss:  0.437, Seconds: 6.58
# Average loss for this update: 0.446
# New Record!
# Epoch  45/100 Batch   40/88 - Loss:  0.508, Seconds: 9.01
# Average loss for this update: 0.629
# No Improvement.
# Epoch  45/100 Batch   60/88 - Loss:  0.730, Seconds: 16.84
# Epoch  45/100 Batch   80/88 - Loss:  0.902, Seconds: 25.02
# Average loss for this update: 0.889
# No Improvement.
# Epoch  46/100 Batch   20/88 - Loss:  0.425, Seconds: 5.86
# Average loss for this update: 0.432
# New Record!
# Epoch  46/100 Batch   40/88 - Loss:  0.488, Seconds: 9.50
# Average loss for this update: 0.614
# No Improvement.
# Epoch  46/100 Batch   60/88 - Loss:  0.719, Seconds: 18.49
# Epoch  46/100 Batch   80/88 - Loss:  0.890, Seconds: 24.57
# Average loss for this update: 0.879
# No Improvement.
# Epoch  47/100 Batch   20/88 - Loss:  0.402, Seconds: 6.58
# Average loss for this update: 0.412
# New Record!
# Epoch  47/100 Batch   40/88 - Loss:  0.479, Seconds: 9.46
# Average loss for this update: 0.596
# No Improvement.
# Epoch  47/100 Batch   60/88 - Loss:  0.693, Seconds: 17.46
# Epoch  47/100 Batch   80/88 - Loss:  0.879, Seconds: 25.31
# Average loss for this update: 0.865
# No Improvement.
# Epoch  48/100 Batch   20/88 - Loss:  0.401, Seconds: 6.98
# Average loss for this update: 0.413
# No Improvement.
# Epoch  48/100 Batch   40/88 - Loss:  0.472, Seconds: 8.92
# Average loss for this update: 0.577
# No Improvement.
# Epoch  48/100 Batch   60/88 - Loss:  0.669, Seconds: 16.48
# Epoch  48/100 Batch   80/88 - Loss:  0.864, Seconds: 24.14
# Average loss for this update: 0.849
# No Improvement.
# Epoch  49/100 Batch   20/88 - Loss:  0.382, Seconds: 6.27
# Average loss for this update: 0.392
# New Record!
# Epoch  49/100 Batch   40/88 - Loss:  0.452, Seconds: 9.06
# Average loss for this update: 0.564
# No Improvement.
# Epoch  49/100 Batch   60/88 - Loss:  0.658, Seconds: 17.51
# Epoch  49/100 Batch   80/88 - Loss:  0.849, Seconds: 24.85
# Average loss for this update: 0.834
# No Improvement.
# Epoch  50/100 Batch   20/88 - Loss:  0.366, Seconds: 6.12
# Average loss for this update: 0.377
# New Record!
# Epoch  50/100 Batch   40/88 - Loss:  0.432, Seconds: 9.08
# Average loss for this update: 0.545
# No Improvement.
# Epoch  50/100 Batch   60/88 - Loss:  0.640, Seconds: 17.68
# Epoch  50/100 Batch   80/88 - Loss:  0.836, Seconds: 27.60
# Average loss for this update: 0.82
# No Improvement.
# Epoch  51/100 Batch   20/88 - Loss:  0.359, Seconds: 6.48
# Average loss for this update: 0.368
# New Record!
# Epoch  51/100 Batch   40/88 - Loss:  0.424, Seconds: 9.10
# Average loss for this update: 0.537
# No Improvement.
# Epoch  51/100 Batch   60/88 - Loss:  0.635, Seconds: 18.18
# Epoch  51/100 Batch   80/88 - Loss:  0.822, Seconds: 25.15
# Average loss for this update: 0.81
# No Improvement.
# Epoch  52/100 Batch   20/88 - Loss:  0.353, Seconds: 5.78
# Average loss for this update: 0.365
# New Record!
# Epoch  52/100 Batch   40/88 - Loss:  0.426, Seconds: 9.37
# Average loss for this update: 0.532
# No Improvement.
# Epoch  52/100 Batch   60/88 - Loss:  0.623, Seconds: 17.43
# Epoch  52/100 Batch   80/88 - Loss:  0.812, Seconds: 24.05
# Average loss for this update: 0.799
# No Improvement.
# Epoch  53/100 Batch   20/88 - Loss:  0.341, Seconds: 6.66
# Average loss for this update: 0.351
# New Record!
# Epoch  53/100 Batch   40/88 - Loss:  0.411, Seconds: 10.46
# Average loss for this update: 0.524
# No Improvement.
# Epoch  53/100 Batch   60/88 - Loss:  0.616, Seconds: 18.04
# Epoch  53/100 Batch   80/88 - Loss:  0.800, Seconds: 24.53
# Average loss for this update: 0.789
# No Improvement.
# Epoch  54/100 Batch   20/88 - Loss:  0.328, Seconds: 6.38
# Average loss for this update: 0.338
# New Record!
# Epoch  54/100 Batch   40/88 - Loss:  0.396, Seconds: 8.97
# Average loss for this update: 0.505
# No Improvement.
# Epoch  54/100 Batch   60/88 - Loss:  0.593, Seconds: 16.82
# Epoch  54/100 Batch   80/88 - Loss:  0.792, Seconds: 25.76
# Average loss for this update: 0.776
# No Improvement.
# Epoch  55/100 Batch   20/88 - Loss:  0.325, Seconds: 6.71
# Average loss for this update: 0.334
# New Record!
# Epoch  55/100 Batch   40/88 - Loss:  0.385, Seconds: 9.85
# Average loss for this update: 0.489
# No Improvement.
# Epoch  55/100 Batch   60/88 - Loss:  0.576, Seconds: 16.21
# Epoch  55/100 Batch   80/88 - Loss:  0.779, Seconds: 25.23
# Average loss for this update: 0.764
# No Improvement.
# Epoch  56/100 Batch   20/88 - Loss:  0.311, Seconds: 5.97
# Average loss for this update: 0.322
# New Record!
# Epoch  56/100 Batch   40/88 - Loss:  0.378, Seconds: 10.95
# Average loss for this update: 0.481
# No Improvement.
# Epoch  56/100 Batch   60/88 - Loss:  0.566, Seconds: 16.61
# Epoch  56/100 Batch   80/88 - Loss:  0.766, Seconds: 24.89
# Average loss for this update: 0.751
# No Improvement.
# Epoch  57/100 Batch   20/88 - Loss:  0.304, Seconds: 5.63
# Average loss for this update: 0.317
# New Record!
# Epoch  57/100 Batch   40/88 - Loss:  0.375, Seconds: 10.05
# Average loss for this update: 0.472
# No Improvement.
# Epoch  57/100 Batch   60/88 - Loss:  0.554, Seconds: 16.64
# Epoch  57/100 Batch   80/88 - Loss:  0.752, Seconds: 25.18
# Average loss for this update: 0.738
# No Improvement.
# Epoch  58/100 Batch   20/88 - Loss:  0.297, Seconds: 5.70
# Average loss for this update: 0.308
# New Record!
# Epoch  58/100 Batch   40/88 - Loss:  0.359, Seconds: 9.03
# Average loss for this update: 0.454
# No Improvement.
# Epoch  58/100 Batch   60/88 - Loss:  0.538, Seconds: 18.55
# Epoch  80/100 Batch   20/88 - Loss:  0.186, Seconds: 6.01
# Average loss for this update: 0.195
# New Record!
# Epoch  80/100 Batch   40/88 - Loss:  0.235, Seconds: 9.58
# Average loss for this update: 0.297
# No Improvement.
# Epoch  80/100 Batch   60/88 - Loss:  0.353, Seconds: 17.30
# Epoch  80/100 Batch   80/88 - Loss:  0.539, Seconds: 24.94
# Average loss for this update: 0.532
# No Improvement.
# Epoch  81/100 Batch   20/88 - Loss:  0.180, Seconds: 7.26
# Average loss for this update: 0.19
# New Record!
# Epoch  81/100 Batch   40/88 - Loss:  0.231, Seconds: 10.62
# Average loss for this update: 0.293
# No Improvement.
# Epoch  81/100 Batch   60/88 - Loss:  0.348, Seconds: 17.32
# Epoch  81/100 Batch   80/88 - Loss:  0.532, Seconds: 26.09
# Average loss for this update: 0.523
# No Improvement.
# Epoch  82/100 Batch   20/88 - Loss:  0.176, Seconds: 6.21
# Average loss for this update: 0.183
# New Record!
# Epoch  82/100 Batch   40/88 - Loss:  0.219, Seconds: 10.00
# Average loss for this update: 0.284
# No Improvement.
# Epoch  82/100 Batch   60/88 - Loss:  0.339, Seconds: 16.94
# Epoch  82/100 Batch   80/88 - Loss:  0.527, Seconds: 27.24
# Average loss for this update: 0.521
# No Improvement.
# Epoch  83/100 Batch   20/88 - Loss:  0.177, Seconds: 6.88
# Average loss for this update: 0.185
# No Improvement.
# Epoch  83/100 Batch   40/88 - Loss:  0.228, Seconds: 9.88
# Average loss for this update: 0.293
# No Improvement.
# Epoch  83/100 Batch   60/88 - Loss:  0.346, Seconds: 16.91
# Epoch  83/100 Batch   80/88 - Loss:  0.526, Seconds: 27.12
# Average loss for this update: 0.519
# No Improvement.
# Epoch  84/100 Batch   20/88 - Loss:  0.177, Seconds: 6.34
# Average loss for this update: 0.184
# No Improvement.
# Epoch  84/100 Batch   40/88 - Loss:  0.224, Seconds: 10.38
# Average loss for this update: 0.289
# No Improvement.
# Epoch  84/100 Batch   60/88 - Loss:  0.344, Seconds: 17.26
# Epoch  84/100 Batch   80/88 - Loss:  0.517, Seconds: 24.56
# Average loss for this update: 0.512
# No Improvement.
# Epoch  85/100 Batch   20/88 - Loss:  0.169, Seconds: 6.08
# Average loss for this update: 0.178
# New Record!
# Epoch  85/100 Batch   40/88 - Loss:  0.222, Seconds: 9.70
# Average loss for this update: 0.284
# No Improvement.
# Epoch  85/100 Batch   60/88 - Loss:  0.336, Seconds: 18.39
# Epoch  85/100 Batch   80/88 - Loss:  0.511, Seconds: 27.74
# Average loss for this update: 0.504
# No Improvement.
# Epoch  86/100 Batch   20/88 - Loss:  0.172, Seconds: 5.72
# Average loss for this update: 0.179
# No Improvement.
# Epoch  86/100 Batch   40/88 - Loss:  0.218, Seconds: 10.09
# Average loss for this update: 0.276
# No Improvement.
# Epoch  86/100 Batch   60/88 - Loss:  0.327, Seconds: 17.67
# Epoch  86/100 Batch   80/88 - Loss:  0.506, Seconds: 26.88
# Average loss for this update: 0.5
# No Improvement.
# Epoch  87/100 Batch   20/88 - Loss:  0.165, Seconds: 6.82
# Average loss for this update: 0.175
# New Record!
# Epoch  87/100 Batch   40/88 - Loss:  0.213, Seconds: 10.53
# Average loss for this update: 0.27
# No Improvement.
# Epoch  87/100 Batch   60/88 - Loss:  0.320, Seconds: 18.10
# Epoch  87/100 Batch   80/88 - Loss:  0.502, Seconds: 26.59
# Average loss for this update: 0.495
# No Improvement.
# Epoch  88/100 Batch   20/88 - Loss:  0.160, Seconds: 6.26
# Average loss for this update: 0.172
# New Record!
# Epoch  88/100 Batch   40/88 - Loss:  0.215, Seconds: 10.61
# Average loss for this update: 0.274
# No Improvement.
# Epoch  88/100 Batch   60/88 - Loss:  0.326, Seconds: 18.17
# Epoch  88/100 Batch   80/88 - Loss:  0.495, Seconds: 27.33
# Average loss for this update: 0.49
# No Improvement.
# Epoch  89/100 Batch   20/88 - Loss:  0.169, Seconds: 6.13
# Average loss for this update: 0.175
# No Improvement.
# Epoch  89/100 Batch   40/88 - Loss:  0.205, Seconds: 10.08
# Average loss for this update: 0.263
# No Improvement.
# Epoch  89/100 Batch   60/88 - Loss:  0.314, Seconds: 16.40
# Epoch  89/100 Batch   80/88 - Loss:  0.489, Seconds: 25.72
# Average loss for this update: 0.484
# No Improvement.
# Epoch  90/100 Batch   20/88 - Loss:  0.161, Seconds: 5.70
# Average loss for this update: 0.171
# New Record!
# Epoch  90/100 Batch   40/88 - Loss:  0.205, Seconds: 9.30
# Average loss for this update: 0.263
# No Improvement.
# Epoch  90/100 Batch   60/88 - Loss:  0.315, Seconds: 19.66
# Epoch  90/100 Batch   80/88 - Loss:  0.482, Seconds: 24.12
# Average loss for this update: 0.476
# No Improvement.
# Epoch  91/100 Batch   20/88 - Loss:  0.161, Seconds: 5.63
# Average loss for this update: 0.169
# New Record!
# Epoch  91/100 Batch   40/88 - Loss:  0.200, Seconds: 9.23
# Average loss for this update: 0.257
# No Improvement.
# Epoch  91/100 Batch   60/88 - Loss:  0.309, Seconds: 17.41
# Epoch  91/100 Batch   80/88 - Loss:  0.477, Seconds: 26.81
# Average loss for this update: 0.472
# No Improvement.
# Epoch  92/100 Batch   20/88 - Loss:  0.156, Seconds: 6.84
# Average loss for this update: 0.164
# New Record!
# Epoch  92/100 Batch   40/88 - Loss:  0.197, Seconds: 9.64
# Average loss for this update: 0.251
# No Improvement.
# Epoch  92/100 Batch   60/88 - Loss:  0.301, Seconds: 17.90
# Epoch  92/100 Batch   80/88 - Loss:  0.475, Seconds: 24.32
# Average loss for this update: 0.47
# No Improvement.
# Epoch  93/100 Batch   20/88 - Loss:  0.151, Seconds: 5.91
# Average loss for this update: 0.16
# New Record!
# Epoch  93/100 Batch   40/88 - Loss:  0.199, Seconds: 9.03
# Average loss for this update: 0.249
# No Improvement.
# Epoch  93/100 Batch   60/88 - Loss:  0.293, Seconds: 19.22
# Epoch  93/100 Batch   80/88 - Loss:  0.472, Seconds: 25.86
# Average loss for this update: 0.464
# No Improvement.
# Epoch  94/100 Batch   20/88 - Loss:  0.153, Seconds: 6.05
# Average loss for this update: 0.16
# New Record!
# Epoch  94/100 Batch   40/88 - Loss:  0.194, Seconds: 9.48
# Average loss for this update: 0.245
# No Improvement.
# Epoch  94/100 Batch   60/88 - Loss:  0.288, Seconds: 19.35
# Epoch  94/100 Batch   80/88 - Loss:  0.458, Seconds: 25.74
# Average loss for this update: 0.452
# No Improvement.
# Epoch  95/100 Batch   20/88 - Loss:  0.147, Seconds: 6.06
# Average loss for this update: 0.157
# New Record!
# Epoch  95/100 Batch   40/88 - Loss:  0.189, Seconds: 9.49
# Average loss for this update: 0.239
# No Improvement.
# Epoch  95/100 Batch   60/88 - Loss:  0.286, Seconds: 19.13
# Epoch  95/100 Batch   80/88 - Loss:  0.446, Seconds: 24.76
# Average loss for this update: 0.442
# No Improvement.
# Epoch  96/100 Batch   20/88 - Loss:  0.144, Seconds: 5.74
# Average loss for this update: 0.152
# New Record!
# Epoch  96/100 Batch   40/88 - Loss:  0.184, Seconds: 9.24
# Average loss for this update: 0.239
# No Improvement.
# Epoch  96/100 Batch   60/88 - Loss:  0.285, Seconds: 18.55
# Epoch  96/100 Batch   80/88 - Loss:  0.445, Seconds: 24.68
# Average loss for this update: 0.438
# No Improvement.
# Epoch  97/100 Batch   20/88 - Loss:  0.137, Seconds: 6.72
# Average loss for this update: 0.147
# New Record!
# Epoch  97/100 Batch   40/88 - Loss:  0.180, Seconds: 9.63
# Average loss for this update: 0.231
# No Improvement.
# Epoch  97/100 Batch   60/88 - Loss:  0.278, Seconds: 18.64
# Epoch  97/100 Batch   80/88 - Loss:  0.438, Seconds: 24.72
# Average loss for this update: 0.434
# No Improvement.
# Epoch  98/100 Batch   20/88 - Loss:  0.135, Seconds: 5.97
# Average loss for this update: 0.142
# New Record!
# Epoch  98/100 Batch   40/88 - Loss:  0.178, Seconds: 9.63
# Average loss for this update: 0.228
# No Improvement.
# Epoch  98/100 Batch   60/88 - Loss:  0.270, Seconds: 17.33
# Epoch  98/100 Batch   80/88 - Loss:  0.434, Seconds: 24.30
# Average loss for this update: 0.428
# No Improvement.
# Epoch  99/100 Batch   20/88 - Loss:  0.133, Seconds: 5.64
# Average loss for this update: 0.141
# New Record!
# Epoch  99/100 Batch   40/88 - Loss:  0.177, Seconds: 10.79
# Average loss for this update: 0.228
# No Improvement.
# Epoch  99/100 Batch   60/88 - Loss:  0.271, Seconds: 17.80
# Epoch  99/100 Batch   80/88 - Loss:  0.431, Seconds: 24.41
# Average loss for this update: 0.427
# No Improvement.
# Epoch 100/100 Batch   20/88 - Loss:  0.133, Seconds: 6.12
# Average loss for this update: 0.14
# New Record!
# Epoch 100/100 Batch   40/88 - Loss:  0.175, Seconds: 9.29
# Average loss for this update: 0.223
# No Improvement.
# Epoch 100/100 Batch   60/88 - Loss:  0.262, Seconds: 17.90
# Epoch 100/100 Batch   80/88 - Loss:  0.432, Seconds: 24.34
# Average loss for this update: 0.426
# No Improvement.

# %%
checkpoint = "drive/My Drive/Colab Notebooks/best_model.ckpt" 

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)
    names = []
    [names.append(n.name) for n in loaded_graph.as_graph_def().node]
names
# Out:
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
# ['input',
#  'targets',
#  'learning_rate',
#  'keep_prob',
#  'summary_length',
#  'Const',
#  'max_dec_len',
#  'text_length',
#  'ReverseV2/axis',
#  'ReverseV2',
#  'embedding_lookup/params_0',
#  'embedding_lookup/axis',
#  'embedding_lookup',
#  'embedding_lookup/Identity',
#  'encoder_0/DropoutWrapperInit/Const',
#  'encoder_0/DropoutWrapperInit/Const_1',
#  'encoder_0/DropoutWrapperInit_1/Const',
#  'encoder_0/DropoutWrapperInit_1/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Rank',
#  'encoder_0/bidirectional_rnn/fw/fw/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/range',
#  'encoder_0/bidirectional_rnn/fw/fw/concat/values_0',
#  'encoder_0/bidirectional_rnn/fw/fw/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/transpose',
#  'encoder_0/bidirectional_rnn/fw/fw/sequence_length',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_1',
#  'encoder_0/bidirectional_rnn/fw/fw/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/Equal',
#  'encoder_0/bidirectional_rnn/fw/fw/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/All',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert/data_0',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert/data_2',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert',
#  'encoder_0/bidirectional_rnn/fw/fw/CheckSeqLen',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_3',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2',
#  'encoder_0/bidirectional_rnn/fw/fw/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/ExpandDims',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_1/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_1',
#  'encoder_0/bidirectional_rnn/fw/fw/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/zeros',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_2',
#  'encoder_0/bidirectional_rnn/fw/fw/Min',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_3',
#  'encoder_0/bidirectional_rnn/fw/fw/Max',
#  'encoder_0/bidirectional_rnn/fw/fw/time',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArray',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArray_1',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_0/bidirectional_rnn/fw/fw/Maximum/x',
#  'encoder_0/bidirectional_rnn/fw/fw/Maximum',
#  'encoder_0/bidirectional_rnn/fw/fw/Minimum',
#  'encoder_0/bidirectional_rnn/fw/fw/while/iteration_counter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less_1/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/LogicalAnd',
#  'encoder_0/bidirectional_rnn/fw/fw/while/LoopCond',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/GreaterEqual/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/GreaterEqual',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/min',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/max',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/sub/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/truediv/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/truediv',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/GreaterEqual',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/Cast',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/mul_1',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Assign',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/read',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Assign',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/read',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/split/split_dim',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/split',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add_1/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_4',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_4',
#  'encoder_0/bidirectional_rnn/fw/fw/Rank_1',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1/start',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2/values_0',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2',
#  'encoder_0/bidirectional_rnn/fw/fw/transpose_1',
#  'encoder_0/bidirectional_rnn/bw/ReverseSequence',
#  'encoder_0/bidirectional_rnn/bw/bw/Rank',
#  'encoder_0/bidirectional_rnn/bw/bw/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/range',
#  'encoder_0/bidirectional_rnn/bw/bw/concat/values_0',
#  'encoder_0/bidirectional_rnn/bw/bw/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/transpose',
#  'encoder_0/bidirectional_rnn/bw/bw/sequence_length',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_1',
#  'encoder_0/bidirectional_rnn/bw/bw/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/Equal',
#  'encoder_0/bidirectional_rnn/bw/bw/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/All',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert/data_0',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert/data_2',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert',
#  'encoder_0/bidirectional_rnn/bw/bw/CheckSeqLen',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_3',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2',
#  'encoder_0/bidirectional_rnn/bw/bw/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/ExpandDims',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_1/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_1',
#  'encoder_0/bidirectional_rnn/bw/bw/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/zeros',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_2',
#  'encoder_0/bidirectional_rnn/bw/bw/Min',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_3',
#  'encoder_0/bidirectional_rnn/bw/bw/Max',
#  'encoder_0/bidirectional_rnn/bw/bw/time',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArray',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArray_1',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_0/bidirectional_rnn/bw/bw/Maximum/x',
#  'encoder_0/bidirectional_rnn/bw/bw/Maximum',
#  'encoder_0/bidirectional_rnn/bw/bw/Minimum',
#  'encoder_0/bidirectional_rnn/bw/bw/while/iteration_counter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less_1/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/LogicalAnd',
#  'encoder_0/bidirectional_rnn/bw/bw/while/LoopCond',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/GreaterEqual/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/GreaterEqual',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/min',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/max',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/sub/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/truediv/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/truediv',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/GreaterEqual',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/Cast',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/mul_1',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Assign',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/read',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Assign',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/read',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/split/split_dim',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/split',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add_1/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_4',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_4',
#  'encoder_0/bidirectional_rnn/bw/bw/Rank_1',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1/start',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2/values_0',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2',
#  'encoder_0/bidirectional_rnn/bw/bw/transpose_1',
#  'encoder_0/ReverseSequence',
#  'encoder_1/DropoutWrapperInit/Const',
#  'encoder_1/DropoutWrapperInit/Const_1',
#  'encoder_1/DropoutWrapperInit_1/Const',
#  'encoder_1/DropoutWrapperInit_1/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Rank',
#  'encoder_1/bidirectional_rnn/fw/fw/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/range',
#  'encoder_1/bidirectional_rnn/fw/fw/concat/values_0',
#  'encoder_1/bidirectional_rnn/fw/fw/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/transpose',
#  'encoder_1/bidirectional_rnn/fw/fw/sequence_length',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_1',
#  'encoder_1/bidirectional_rnn/fw/fw/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/Equal',
#  'encoder_1/bidirectional_rnn/fw/fw/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/All',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert/data_0',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert/data_2',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert',
#  'encoder_1/bidirectional_rnn/fw/fw/CheckSeqLen',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_3',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2',
#  'encoder_1/bidirectional_rnn/fw/fw/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/ExpandDims',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_1/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_1',
#  'encoder_1/bidirectional_rnn/fw/fw/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/zeros',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_2',
#  'encoder_1/bidirectional_rnn/fw/fw/Min',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_3',
#  'encoder_1/bidirectional_rnn/fw/fw/Max',
#  'encoder_1/bidirectional_rnn/fw/fw/time',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArray',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArray_1',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_1/bidirectional_rnn/fw/fw/Maximum/x',
#  'encoder_1/bidirectional_rnn/fw/fw/Maximum',
#  'encoder_1/bidirectional_rnn/fw/fw/Minimum',
#  'encoder_1/bidirectional_rnn/fw/fw/while/iteration_counter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less_1/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/LogicalAnd',
#  'encoder_1/bidirectional_rnn/fw/fw/while/LoopCond',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/GreaterEqual/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/GreaterEqual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/min',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/max',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/sub/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/truediv/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/truediv',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/GreaterEqual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/Cast',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/mul_1',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Assign',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/read',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Assign',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/read',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/split/split_dim',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/split',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add_1/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_4',
#  'encoder_1/bidirectional_rnn/fw/fw/Rank_1',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1/start',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2/values_0',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2',
#  'encoder_1/bidirectional_rnn/fw/fw/transpose_1',
#  'encoder_1/bidirectional_rnn/bw/ReverseSequence',
#  'encoder_1/bidirectional_rnn/bw/bw/Rank',
#  'encoder_1/bidirectional_rnn/bw/bw/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/range',
#  'encoder_1/bidirectional_rnn/bw/bw/concat/values_0',
#  'encoder_1/bidirectional_rnn/bw/bw/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/transpose',
#  'encoder_1/bidirectional_rnn/bw/bw/sequence_length',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_1',
#  'encoder_1/bidirectional_rnn/bw/bw/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/Equal',
#  'encoder_1/bidirectional_rnn/bw/bw/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/All',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert/data_0',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert/data_2',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert',
#  'encoder_1/bidirectional_rnn/bw/bw/CheckSeqLen',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_3',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2',
#  'encoder_1/bidirectional_rnn/bw/bw/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/ExpandDims',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_1/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_1',
#  'encoder_1/bidirectional_rnn/bw/bw/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/zeros',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_2',
#  'encoder_1/bidirectional_rnn/bw/bw/Min',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_3',
#  'encoder_1/bidirectional_rnn/bw/bw/Max',
#  'encoder_1/bidirectional_rnn/bw/bw/time',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArray',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArray_1',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_1/bidirectional_rnn/bw/bw/Maximum/x',
#  'encoder_1/bidirectional_rnn/bw/bw/Maximum',
#  'encoder_1/bidirectional_rnn/bw/bw/Minimum',
#  'encoder_1/bidirectional_rnn/bw/bw/while/iteration_counter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less_1/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/LogicalAnd',
#  'encoder_1/bidirectional_rnn/bw/bw/while/LoopCond',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/GreaterEqual/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/GreaterEqual',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/min',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/max',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/sub/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/truediv/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/truediv',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/GreaterEqual',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/Cast',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/mul_1',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Assign',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/read',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Assign',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/read',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/split/split_dim',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/split',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add_1/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_4',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_4',
#  'encoder_1/bidirectional_rnn/bw/bw/Rank_1',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1/start',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2/values_0',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2',
#  'encoder_1/bidirectional_rnn/bw/bw/transpose_1',
#  'encoder_1/ReverseSequence',
#  'concat/axis',
#  'concat',
#  'StridedSlice/begin',
#  'StridedSlice/end',
#  'StridedSlice/strides',
#  'StridedSlice',
#  'Fill/dims',
#  'Fill/value',
#  'Fill',
#  'concat_1/axis',
#  'concat_1',
#  'embedding_lookup_1/params_0',
#  'embedding_lookup_1/axis',
#  'embedding_lookup_1',
#  'embedding_lookup_1/Identity',
#  'decoder_0/DropoutWrapperInit/Const',
#  'decoder_0/DropoutWrapperInit/Const_1',
#  'decoder_1/DropoutWrapperInit/Const',
#  'decoder_1/DropoutWrapperInit/Const_1',
#  'BahdanauAttention/Shape',
#  'BahdanauAttention/strided_slice/stack',
#  'BahdanauAttention/strided_slice/stack_1',
#  'BahdanauAttention/strided_slice/stack_2',
#  'BahdanauAttention/strided_slice',
#  'BahdanauAttention/SequenceMask/Const',
#  'BahdanauAttention/SequenceMask/Const_1',
#  'BahdanauAttention/SequenceMask/Range',
#  'BahdanauAttention/SequenceMask/ExpandDims/dim',
#  'BahdanauAttention/SequenceMask/ExpandDims',
#  'BahdanauAttention/SequenceMask/Cast',
#  'BahdanauAttention/SequenceMask/Less',
#  'BahdanauAttention/SequenceMask/Cast_1',
#  'BahdanauAttention/ones/shape_as_tensor',
#  'BahdanauAttention/ones/Const',
#  'BahdanauAttention/ones',
#  'BahdanauAttention/Shape_1',
#  'BahdanauAttention/concat/axis',
#  'BahdanauAttention/concat',
#  'BahdanauAttention/Reshape',
#  'BahdanauAttention/mul',
#  'memory_layer/kernel/Initializer/random_uniform/shape',
#  'memory_layer/kernel/Initializer/random_uniform/min',
#  'memory_layer/kernel/Initializer/random_uniform/max',
#  'memory_layer/kernel/Initializer/random_uniform/RandomUniform',
#  'memory_layer/kernel/Initializer/random_uniform/sub',
#  'memory_layer/kernel/Initializer/random_uniform/mul',
#  'memory_layer/kernel/Initializer/random_uniform',
#  'memory_layer/kernel',
#  'memory_layer/kernel/Assign',
#  'memory_layer/kernel/read',
#  'BahdanauAttention/memory_layer/Tensordot/axes',
#  'BahdanauAttention/memory_layer/Tensordot/free',
#  'BahdanauAttention/memory_layer/Tensordot/Shape',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2/axis',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2_1/axis',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2_1',
#  'BahdanauAttention/memory_layer/Tensordot/Const',
#  'BahdanauAttention/memory_layer/Tensordot/Prod',
#  'BahdanauAttention/memory_layer/Tensordot/Const_1',
#  'BahdanauAttention/memory_layer/Tensordot/Prod_1',
#  'BahdanauAttention/memory_layer/Tensordot/concat/axis',
#  'BahdanauAttention/memory_layer/Tensordot/concat',
#  'BahdanauAttention/memory_layer/Tensordot/stack',
#  'BahdanauAttention/memory_layer/Tensordot/transpose',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape',
#  'BahdanauAttention/memory_layer/Tensordot/transpose_1/perm',
#  'BahdanauAttention/memory_layer/Tensordot/transpose_1',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape_1/shape',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape_1',
#  'BahdanauAttention/memory_layer/Tensordot/MatMul',
#  'BahdanauAttention/memory_layer/Tensordot/Const_2',
#  'BahdanauAttention/memory_layer/Tensordot/concat_1/axis',
#  'BahdanauAttention/memory_layer/Tensordot/concat_1',
#  'BahdanauAttention/memory_layer/Tensordot',
#  'BahdanauAttention/Shape_2',
#  'BahdanauAttention/strided_slice_1/stack',
#  'BahdanauAttention/strided_slice_1/stack_1',
#  'BahdanauAttention/strided_slice_1/stack_2',
#  'BahdanauAttention/strided_slice_1',
#  'BahdanauAttention/Shape_3',
#  'BahdanauAttention/strided_slice_2/stack',
#  'BahdanauAttention/strided_slice_2/stack_1',
#  'BahdanauAttention/strided_slice_2/stack_2',
#  'BahdanauAttention/strided_slice_2',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_4',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_5',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_6',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_7',
#  'AttentionWrapperZeroState/assert_equal_1/x',
#  'AttentionWrapperZeroState/assert_equal_1/Equal',
#  'AttentionWrapperZeroState/assert_equal_1/Const',
#  'AttentionWrapperZeroState/assert_equal_1/All',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_1',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_2',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_3',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_0',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_1',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_2',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_4',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert',
#  'AttentionWrapperZeroState/checked_cell_state',
#  'AttentionWrapperZeroState/checked_cell_state_1',
#  'AttentionWrapperZeroState/Const',
#  'AttentionWrapperZeroState/ExpandDims/dim',
#  'AttentionWrapperZeroState/ExpandDims',
#  'AttentionWrapperZeroState/concat/axis',
#  'AttentionWrapperZeroState/concat',
#  'AttentionWrapperZeroState/zeros/Const',
#  'AttentionWrapperZeroState/zeros',
#  'AttentionWrapperZeroState/Const_1',
#  'AttentionWrapperZeroState/ExpandDims_1/dim',
#  'AttentionWrapperZeroState/ExpandDims_1',
#  'AttentionWrapperZeroState/zeros_1',
#  'AttentionWrapperZeroState/Const_2',
#  'AttentionWrapperZeroState/Const_3',
#  'AttentionWrapperZeroState/concat_1/axis',
#  'AttentionWrapperZeroState/concat_1',
#  'AttentionWrapperZeroState/zeros_2/Const',
#  'AttentionWrapperZeroState/zeros_2',
#  'AttentionWrapperZeroState/Const_4',
#  'AttentionWrapperZeroState/Const_5',
#  'AttentionWrapperZeroState/Const_6',
#  'AttentionWrapperZeroState/ExpandDims_2/dim',
#  'AttentionWrapperZeroState/ExpandDims_2',
#  'AttentionWrapperZeroState/concat_2/axis',
#  'AttentionWrapperZeroState/concat_2',
#  'AttentionWrapperZeroState/zeros_3/Const',
#  'AttentionWrapperZeroState/zeros_3',
#  'AttentionWrapperZeroState/Const_7',
#  'AttentionWrapperZeroState/ExpandDims_3/dim',
#  'AttentionWrapperZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/Size/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/Size',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/is_rank/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/is_rank',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/equal_1/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/equal_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/exclude_partial_shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert/data_0',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert/data_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/Identity',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/Size/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/Size',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/is_rank/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/is_rank',
#  ...]

# %% [markdown]
# ## Making Our Own Summaries

# %%
def text_to_seq(text):
    '''Prepare the text for the model'''
    
    text = clean_text(text)
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in text.split()]

# %%
text=''' 9GAG Limited is a media company.  Our mission is to make the world happier.

The 9GAG services that link to this Privacy Policy provide fun ways for you to create, share, and discover the best content in the world.

When you use these services, you’ll share some information with us. We want to explain clearly what information we collect, why we collect it, how we use it, whom we share it with, and the controls we give you to access, update, and delete your information.

That’s why we’ve written this Privacy Policy. We tried to write it in simple language with minimal legalese so it’s easy for you to understand. If you have any questions about anything in our Privacy Policy, please contact us. 

Information We Collect
There are three basic categories of information we collect:

Information you choose to give us

Information we get when you use our services

Information we get from third parties

Here’s how we collect your information.

How We Collect Information
Information You Choose To Give Us
When you use and interact with our services, we collect the information you choose to share with us. For example, most of our services require you to set up a basic 9GAG account, so we need to collect a few important details about you, such as: a unique username you choose, a password, an e-mail address, and your date of birth. To make it easier for others to find you, we may also ask you to provide us additional information that will be publicly visible on our services, for example a profile picture, a name, or other identifiable information. Our other services, such as commerce products, may also require you to provide us with a debit card or credit card number and its associated account information.

You’ll also provide any information you send through our services, such as post and comment uploads. Keep in mind that the posts and comments you upload can be seen publicly, and can always be saved and copied outside of our services. Please don’t share content you wouldn’t want someone to save or share.

Lastly, when you contact us or communicate with us in any way, we’ll collect any information you give us.

Information We Get When You Use Our Services
When you use our services, we collect information about which services you use and how you use them. For example, we may know what section or post you are reading, when you’re reading it, and how you’re reading it (desktop, mobile browser, or mobile app). Here’s a more detailed explanation of the information we collect when you use our services:

Usage Information. We collect information about your activity through our services. For example:

How you interact with our services, such as what sections you look at, what you search for, what posts and comments you upload, or what posts and comments you upvote or downvote.

Content Information. We collect content you create on our services. For example:

The images, videos, and text you upload

We also collect information about the content you create. For example:

When you created the content

Where you created the content

How you created the content such as device information

We also collect information about how other users interact with your content. For example:

Post upvotes and downvotes

Comments and comment upvotes and downvotes

Device Information. We collect information from and about the devices you use. For example:

Information about your hardware and software, such as hardware model, operating system version, device memory, advertising identifiers, unique application identifiers, unique device identifiers, and language.

Information about your wireless and mobile network connections, such as your type of network connection.

Camera and Photos. Some of our services require us to collect images and other information from your devices’s camera and photos. For example, you won’t be able to upload images or videos from your camera roll unless we can access your camera or media library.

Location Information.  When you use our services, we may collect information about your location. With your permission, we may also collect information about your precise location using methods that include GPS, wireless networks, and Wi-Fi access points.

Information Collected by Cookies and Other Technologies. We may use cookies and other technologies such as web beacons, web storage, and unique advertising identifiers to collect information about your activity, browser, and device. We may use these technologies to collect information when you interact with services we offer through one of our partners, such as advertising and commerce features. Most web browsers are set to accept cookies by default. It is up to you to move or reject browser cookies through the settings on your browser or device. Removing or rejecting cookies may affect our service function and availability.

Log Information.  We also collect log information when you use our services. For example:

Details about how you’ve used our services.

Device information, such as web browser type and language.

Access times.

Pages and content viewed.

IP address.

Identifiers associated with cookies or other technologies that may uniquely identify your device or browser.

Pages you visited before or after visiting our website or using our service.

Information We Collect From Third Parties
We may collect information from our affiliates and third parties. For example:

If you use your Google or Facebook account to sign up or sign in to our services, we may receive information so you can create or access your 9GAG account.

If you interact with one of our advertisers, they may share information with us to help target or measure ad performance.

How We Use Information
We use your information to provide you with the best products and services we can build and improve. Here’s what we use this information for:

To develop, maintain, improve, deliver, and protect our products and services.

Monitor and analyze trends and usages of our products and services.

Send you communications, including by e-mail. Examples include using e-mail to respond to support inquiries, or to share information about our products, services, and promotional offers that we think may interest you.

Personalize our services by showing you better and more relevant content.

Provide ad targeting and measurement, including the use of your precise location information to show relevant ads.

Enhance and enforce the safety and security of our products and services.

Verify your identity and prevent fraud, or other authorized and illegal activity.

Use information we’ve collected cookies and other data to enhance our services and products.

Enforce our Terms of Service, Community Rules, and other usage policies.

How We Share Information
We may share information about you in the following ways:

With other 9GAG Users. We may share information with other 9GAG users. Examples include:

Information about you, such as your name, username, and profile pictures.

Information you upload, such as image or video posts.

Information about how you interacted with our services, such as the content you saved, the comments you post, and the content you upvote and downvote.

With all 9GAG Users, our business partners, and the general public. We may share information with all 9GAG users, our business partners, and the general public. Examples include:

Public information like your name, username, and profile pictures.

Content submissions and saved content set to be viewable by everyone.

Content from our services that you share on other services, such as Facebook or Pinterest.

With our affiliates. We may share information with the entities within the 9GAG Limited family of companies.

With third parties. We may share your information with third parties. Examples include:

With service providers. We may share information about you with service providers who perform services on our behalf. 

With business partners. We may share information about you with business partners that provide services and functionality. 

With third parties for legal reasons.  We may share information about you if we reasonably believe that disclosing the information is necessary. Examples include:

To comply with any valid legal process, governmental request, or applicable law, rule or regulation.

To investigate, enforce, or remedy potential Terms of Service violations

To protect the safety, rights, and property of 9GAG, our users, or others.

To detect and resolve any fraud or security matters or concerns.

With third parties as part of a merger or acquisition. If 9GAG Limited gets involved with a merger, asset sale, financing, liquidation, bankruptcy, or acquisition of all or some portion of our business to another company, we may share your information with the company before, during, and after the transaction.

We may also share aggregated, non-personally identifiable, or de-identified information with third parties, such as advertisers.

Third-Party Content and Integrations
Our services may contain third-party links and search results, include third-party integrations, or offer a co-branded or third-party-branded-service. Through these links, third-party integrations, and co-branded or third-party-branded services, you may be providing information, including personal information, directly to the third party, to us, or to both. You acknowledge and agree that we are not responsible for how those third parties collect or use your information. We encourage you to review the privacy policies of every third-party service you visit or use, including those third parties you interact with through our services.

Analytics and Advertising Services
Provided by Others
We may let other companies use cookies, web beacons, and similar technologies on our services. These companies may collect information about how you use our services over time, and combine it with similar information from other services and companies. This information may be used to analyze and track data, determine the popularity of certain content, and under your online activity, among other things.

Some companies, including our affiliates, may use information collected on our services to measure the performance of ads and deliver more relevant ads, including on third-party websites and apps.

Provided by Us
We may collect information about your activity on third-party services that use cookies and other technologies provided by us. We use this information to improve your user experience with our services and to improve your advertising services, including measuring the performance of ads and showing you relevant ads. Visit our Advertising Preferences page to learn more about 9GAG advertising and how you can control the information used to select the ads you see.

How Long We Keep Your Information
9GAG stores your information, the posts you upload, and the comments you upload for a period of time. For example:

We store your basic account information, including your name, username, and email address until you ask us to delete them

We store location information for different lengths of time based on how precise it is and which services you use.

We are constantly collecting and updating information about the things you like or dislike, so we can provide you with more relevant data, more relevant ads, and a better user experience.

If you decide to stop using 9GAG, you can ask us to delete your account. 

There may be legal requirements to store your data and we may need to suspend those deletion practices if we receive valid legal process or request asking us to preserve that content, or if we receive reports of abuse or other Terms of Service Violations. We may also need to retain certain information in backup for a limited period of time, or as required by law.

Control over Your Information
At 9GAG, your privacy is important to us. We want you to have control over the information you give us, the information we use, and the information we keep. These are the tools we provide you to control your information:

Download My Data. You can request your data to be sent to you.

Removing Permissions. If you agree to let us use your information, you can change your mind at any time by changing the settings on your device. If you remove permission, certain services may be impacted and may lose functionality.

Deletion. We hope you remain a 9GAG user for life, but if you want to delete your account, please contact us. 

Users in the European Union and European Economic Area
If you’re a user in the European Union or European Economic Area, please note that 9GAG Limited is the data controller of your information. Here’s additional information we would like you to know:

Bases For Using Your Information
Your country only allows us to use your personal information when certain conditions apply or are met. These conditions are called legal bases. At 9GAG, we rely on one of the following bases:

Contract. We may use your information because you’ve entered into an agreement with us. For example, when you buy our merchandise and have accepted our Terms and Services, we may use some of your information to collect payment and to make sure you receive the right product, at the right time, to the right address.

Legitimate Interest. We may use your information because we - or a third party - has a legitimate interest. For example, we need to use your information to provide, maintain and improve our services. This includes protecting your account, uploading your posts and comments, providing customer support, and showing the best content you’ll like. Most of these services are free. To keep the lights on at 9GAG HQ, we may use this information to show you relevant ads. We believe legitimate interest does not outweigh your right to privacy, so we only rely on legitimate interest when we think the way we are using your data does not significantly impact your privacy.

Consent. We may ask for your consent to use your information for specific purposes. If we do, we’ll make sure you can revoke your consent in our services or through your device permissions at any time. Even if we’re not relying on consent to use your information, we may ask you for permission to access data such as your location.

Legal obligation. We may use your personal information when we are required to comply with the law, such as when we respond to valid legal process or need to take action to protect our users or employees.

Your Right To Object
You have the right to object to our use of your information. For some data, we’ve provided you with the ability to delete your data if you don’t want us to store or process it anymore. For other data, you can stop our use of your information by disabling the feature altogether. You can do these things on our site or in our apps. If you find other types of information you don’t agree with us using, please contact us.

International Transfers
We may collect your personal information from, transfer it to, and process it in the United States and other countries outside of where you live. When we share information of EU and EEA users outside the EU or EEA, we make sure an adequate transfer mechanism is in place. For internal transfers, we rely on the EU-U.S. and Swiss-U.S. Privacy Shield.

Your Right To Complain
If you’re based in the EU or EEA and have a complaint, you can file your complaint with the supervisory authority in your Member States. For example, if you’re based in the UK, you can file a complaint with the Information Commissioner’s Office. '''

# %%
paragraphs = text.split('\n')
rm_paras = list()
for para in paragraphs:
  if len(para)<200:
    continue
  rm_paras.append(para)

# %%
checkpoint = "drive/My Drive/Colab Notebooks/best_model.ckpt"
print ("\n######################################## ORIGINAL POLICY ##########################################\n")
for para in rm_paras:
  print (para)
print ("\n###################################################################################################\n")
print ("\n@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ SUMMARIZED POLICY @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
for para in rm_paras:
  input_sentence = para
  text = text_to_seq(input_sentence)

  loaded_graph = tf.Graph()
  with tf.Session(graph=loaded_graph) as sess:
      # Load saved model
      loader = tf.train.import_meta_graph(checkpoint + '.meta')
      loader.restore(sess, checkpoint)

      input_data = loaded_graph.get_tensor_by_name('input:0')
      logits = loaded_graph.get_tensor_by_name('predictions:0')
      text_length = loaded_graph.get_tensor_by_name('text_length:0')
      summary_length = loaded_graph.get_tensor_by_name('summary_length:0')
      keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
      
      #Multiply by batch_size to match the model's input parameters
      answer_logits = sess.run(logits, {input_data: [text]*batch_size, 
                                        summary_length: [np.random.randint(5,8)], 
                                        text_length: [len(text)]*batch_size,
                                        keep_prob: 1.0})[0] 

  # Remove the padding from the tweet
  pad = vocab_to_int["<PAD>"] 
  print('\nSummary')
  #print('  Word Ids:       {}'.format([i for i in answer_logits if i != pad]))
  print('  Response Words: {}'.format(" ".join([int_to_vocab[i] for i in answer_logits if i != pad])))
  print ()
print ("\n@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
# Out:
# ######################################## ORIGINAL POLICY ##########################################
#
# When you use these services, you’ll share some information with us. We want to explain clearly what information we collect, why we collect it, how we use it, whom we share it with, and the controls we give you to access, update, and delete your information.
# That’s why we’ve written this Privacy Policy. We tried to write it in simple language with minimal legalese so it’s easy for you to understand. If you have any questions about anything in our Privacy Policy, please contact us.
# When you use and interact with our services, we collect the information you choose to share with us. For example, most of our services require you to set up a basic 9GAG account, so we need to collect a few important details about you, such as: a unique username you choose, a password, an e-mail address, and your date of birth. To make it easier for others to find you, we may also ask you to provide us additional information that will be publicly visible on our services, for example a profile picture, a name, or other identifiable information. Our other services, such as commerce products, may also require you to provide us with a debit card or credit card number and its associated account information.
# You’ll also provide any information you send through our services, such as post and comment uploads. Keep in mind that the posts and comments you upload can be seen publicly, and can always be saved and copied outside of our services. Please don’t share content you wouldn’t want someone to save or share.
# When you use our services, we collect information about which services you use and how you use them. For example, we may know what section or post you are reading, when you’re reading it, and how you’re reading it (desktop, mobile browser, or mobile app). Here’s a more detailed explanation of the information we collect when you use our services:
# Information about your hardware and software, such as hardware model, operating system version, device memory, advertising identifiers, unique application identifiers, unique device identifiers, and language.
# Camera and Photos. Some of our services require us to collect images and other information from your devices’s camera and photos. For example, you won’t be able to upload images or videos from your camera roll unless we can access your camera or media library.
# Location Information.  When you use our services, we may collect information about your location. With your permission, we may also collect information about your precise location using methods that include GPS, wireless networks, and Wi-Fi access points.
# Information Collected by Cookies and Other Technologies. We may use cookies and other technologies such as web beacons, web storage, and unique advertising identifiers to collect information about your activity, browser, and device. We may use these technologies to collect information when you interact with services we offer through one of our partners, such as advertising and commerce features. Most web browsers are set to accept cookies by default. It is up to you to move or reject browser cookies through the settings on your browser or device. Removing or rejecting cookies may affect our service function and availability.
# Send you communications, including by e-mail. Examples include using e-mail to respond to support inquiries, or to share information about our products, services, and promotional offers that we think may interest you.
# With third parties as part of a merger or acquisition. If 9GAG Limited gets involved with a merger, asset sale, financing, liquidation, bankruptcy, or acquisition of all or some portion of our business to another company, we may share your information with the company before, during, and after the transaction.
# Our services may contain third-party links and search results, include third-party integrations, or offer a co-branded or third-party-branded-service. Through these links, third-party integrations, and co-branded or third-party-branded services, you may be providing information, including personal information, directly to the third party, to us, or to both. You acknowledge and agree that we are not responsible for how those third parties collect or use your information. We encourage you to review the privacy policies of every third-party service you visit or use, including those third parties you interact with through our services.
# We may let other companies use cookies, web beacons, and similar technologies on our services. These companies may collect information about how you use our services over time, and combine it with similar information from other services and companies. This information may be used to analyze and track data, determine the popularity of certain content, and under your online activity, among other things.
# We may collect information about your activity on third-party services that use cookies and other technologies provided by us. We use this information to improve your user experience with our services and to improve your advertising services, including measuring the performance of ads and showing you relevant ads. Visit our Advertising Preferences page to learn more about 9GAG advertising and how you can control the information used to select the ads you see.
# There may be legal requirements to store your data and we may need to suspend those deletion practices if we receive valid legal process or request asking us to preserve that content, or if we receive reports of abuse or other Terms of Service Violations. We may also need to retain certain information in backup for a limited period of time, or as required by law.
# At 9GAG, your privacy is important to us. We want you to have control over the information you give us, the information we use, and the information we keep. These are the tools we provide you to control your information:
# Removing Permissions. If you agree to let us use your information, you can change your mind at any time by changing the settings on your device. If you remove permission, certain services may be impacted and may lose functionality.
# Contract. We may use your information because you’ve entered into an agreement with us. For example, when you buy our merchandise and have accepted our Terms and Services, we may use some of your information to collect payment and to make sure you receive the right product, at the right time, to the right address.
# Legitimate Interest. We may use your information because we - or a third party - has a legitimate interest. For example, we need to use your information to provide, maintain and improve our services. This includes protecting your account, uploading your posts and comments, providing customer support, and showing the best content you’ll like. Most of these services are free. To keep the lights on at 9GAG HQ, we may use this information to show you relevant ads. We believe legitimate interest does not outweigh your right to privacy, so we only rely on legitimate interest when we think the way we are using your data does not significantly impact your privacy.
# Consent. We may ask for your consent to use your information for specific purposes. If we do, we’ll make sure you can revoke your consent in our services or through your device permissions at any time. Even if we’re not relying on consent to use your information, we may ask you for permission to access data such as your location.
# Legal obligation. We may use your personal information when we are required to comply with the law, such as when we respond to valid legal process or need to take action to protect our users or employees.
# You have the right to object to our use of your information. For some data, we’ve provided you with the ability to delete your data if you don’t want us to store or process it anymore. For other data, you can stop our use of your information by disabling the feature altogether. You can do these things on our site or in our apps. If you find other types of information you don’t agree with us using, please contact us.
# We may collect your personal information from, transfer it to, and process it in the United States and other countries outside of where you live. When we share information of EU and EEA users outside the EU or EEA, we make sure an adequate transfer mechanism is in place. For internal transfers, we rely on the EU-U.S. and Swiss-U.S. Privacy Shield.
# If you’re based in the EU or EEA and have a complaint, you can file your complaint with the supervisory authority in your Member States. For example, if you’re based in the UK, you can file a complaint with the Information Commissioner’s Office.
#
# ###################################################################################################
#
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ SUMMARIZED POLICY @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we have the following to
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we may also collect information about you
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we also offer services that you
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we are general to share information
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we may compare this information with our
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: in the course of evaluating
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: companies you will not impersonate to provide
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we collect personal information which you provide
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: cookies are information that is used to
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: additionally will only send you
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: in addition to the extent necessary who
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: also on our sites do not
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we may use information about
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we may collect information about you by
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: you may opt out of the
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: information is and to protect
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we also use this information
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: when you receive on our sites or
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: for more information about your use of
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: personal information of a traveler of
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: as we are not responsible for the
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: you may write a worldwide of such
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: we may collect this information if you
#
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
#
# Summary
#   Response Words: at any time you are using
#
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# Create summaries

input_sentence = "When you use and interact with our services, we collect the information you choose to share with us. For example, most of our services require you to set up a basic 9GAG account, so we need to collect a few important details about you, such as: a unique username you choose, a password, an e-mail address, and your date of birth. To make it easier for others to find you, we may also ask you to provide us additional information that will be publicly visible on our services, for example a profile picture, a name, or other identifiable information. Our other services, such as commerce products, may also require you to provide us with a debit card or credit card number and its associated account information.You’ll also provide any information you send through our services, such as post and comment uploads. Keep in mind that the posts and comments you upload can be seen publicly, and can always be saved and copied outside of our services. Please don’t share content you wouldn’t want someone to save or share.Lastly, when you contact us or communicate with us in any way, we’ll collect any information you give us."

text = text_to_seq(input_sentence)

checkpoint = "drive/My Drive/Colab Notebooks/best_model.ckpt"

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    text_length = loaded_graph.get_tensor_by_name('text_length:0')
    summary_length = loaded_graph.get_tensor_by_name('summary_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
    
    #Multiply by batch_size to match the model's input parameters
    answer_logits = sess.run(logits, {input_data: [text]*batch_size, 
                                      summary_length: [np.random.randint(5,8)], 
                                      text_length: [len(text)]*batch_size,
                                      keep_prob: 1.0})[0] 

# Remove the padding from the tweet
pad = vocab_to_int["<PAD>"] 

print('Original Text:', input_sentence)

print('\nText')
print('  Word Ids:    {}'.format([i for i in text]))
print('  Input Words: {}'.format(" ".join([int_to_vocab[i] for i in text])))

print('\nSummary')
print('  Word Ids:       {}'.format([i for i in answer_logits if i != pad]))
print('  Response Words: {}'.format(" ".join([int_to_vocab[i] for i in answer_logits if i != pad])))
# Out:
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/best_model.ckpt
# Original Text: When you use and interact with our services, we collect the information you choose to share with us. For example, most of our services require you to set up a basic 9GAG account, so we need to collect a few important details about you, such as: a unique username you choose, a password, an e-mail address, and your date of birth. To make it easier for others to find you, we may also ask you to provide us additional information that will be publicly visible on our services, for example a profile picture, a name, or other identifiable information. Our other services, such as commerce products, may also require you to provide us with a debit card or credit card number and its associated account information.You’ll also provide any information you send through our services, such as post and comment uploads. Keep in mind that the posts and comments you upload can be seen publicly, and can always be saved and copied outside of our services. Please don’t share content you wouldn’t want someone to save or share.Lastly, when you contact us or communicate with us in any way, we’ll collect any information you give us.
#
# Text
#   Word Ids:    [20, 1425, 23, 103, 10, 245, 99, 186, 40, 23, 504, 441, 1236, 1552, 42, 518, 103, 1333, 601, 1327, 2475, 245, 828, 109, 110, 108, 130, 602, 342, 2066, 267, 982, 89, 90, 190, 45, 186, 410, 10, 1484, 2553, 23, 40, 56, 4358, 107, 339, 10, 23, 1567, 126, 89, 90, 504, 45, 186, 862, 79, 78, 79, 80, 1210, 42, 10, 11680, 90, 45, 10, 482, 23, 266, 974, 9164, 467, 295, 1349, 1045, 268, 2169, 1484, 1133, 1085, 620, 906, 23, 331, 11680, 99, 269, 11680, 313, 1707, 1144, 99, 4399, 332, 186, 167, 186, 1089, 11680, 103, 10, 693, 186]
#   Input Words: use interact services collect information choose share us example services require set basic 9gag account need collect important details unique username choose password e mail address date birth make easier others find may also ask provide us additional information publicly visible services example profile picture name identifiable information services commerce products may also require provide us debit card credit card number associated account information <UNK> also provide information send services post comment uploads keep mind posts comments upload seen publicly always saved copied outside services please <UNK> share content <UNK> want someone save share lastly contact us communicate us way <UNK> collect information give us
#
# Summary
#   Word Ids:       [52, 90, 145, 23, 46, 47]
#   Response Words: we also offer services that you

# %% [markdown]
# PARAGRAPH: "Swift Communications collects the personal information you provide when you use this Site to register for an account, subscribe to one of our newspapers, or submit news items or use our social networking tools such as when you: comment on news stories, create blogs, submit photographs and videos and send public or private messages to your friends on the Site. This includes your contact information, such as your name, e-mail address, postal address and telephone number or your billing information, such as your credit or debit card information and the content of the communications. We process your payment card payments using a third party and only see the last 4 digits of the number and the maker of the card. If you choose to participate in one of our surveys or sweepstakes  we will collect the information you provide in your answers. Information Sent to Us by Your Web Browser. We collect information that is sent to us automatically by your Web browser. This information typically includes your IP address, the identity of your Internet service provider, the name and version of your operating system, the name and version of your browser, the date and time of your visit, and the pages you visit. Please check your browser if you want to learn what information your browser sends or how to change your settings. Generally, we do not link the information provided by your browser to information that identifies you by name. More About IP Addresses. An IP address is a unique number that is automatically assigned to your device when you connect to the Internet. It is used to identify your devices location in cyberspace, so that the information you request can be delivered to you. If you use a dial-up connection or a connection that assigns dynamic IP addresses, your device will be assigned a new IP address each time you connect to the Internet. If, however, your device is permanently connected to the Internet using a static IP address, the IP address assigned to your device will generally be the same each time you use your device. IP addresses do not include your name, email address or other information that identifies you personally, but in some cases, they can be used to identify you. For example, if you have registered with this Site, we may link your IP address to account information that identifies you personally. We may also provide your IP address to our third-party service provider who can use it to identify your state and zip code. This gives us valuable demographic information about the individuals who use this Site. Our service providers are bound by contract to use the IP addresses we provide only for this purpose. In addition, if, for example, we suspect fraud or a threat to the security of this Site, we may share our server logs-which contain users IP addresses-with the appropriate investigative authorities, who could use that information to trace and identify individuals."
#
#
# Heading: how do we use the information
#
# Summary:  service provider, the name and version of your operating system, the name and version of your browser, the date and time of your visit, and the pages you visit. Please check your browser if you want to learn what information your browser sends or how to change your settings. Generally, we do not link the information provided by your browser to information that identifies you by name.
