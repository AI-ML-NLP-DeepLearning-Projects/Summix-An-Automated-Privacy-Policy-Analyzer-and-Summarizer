# %%
#importing libraries
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
import os

# %%
def _create_dictionary_table(text_string):
   
    #removing stop words
    stop_words = set(stopwords.words("english"))
    
    words = word_tokenize(text_string)
    
    #reducing words to their root form
    stem = PorterStemmer()
    
    #creating dictionary for the word frequency table
    frequency_table = dict()
    for wd in words:
        wd = stem.stem(wd)
        if wd in stop_words:
            continue
        if wd in frequency_table:
            frequency_table[wd] += 1
        else:
            frequency_table[wd] = 1

    return frequency_table


def _calculate_sentence_scores(sentences, frequency_table):   

    #algorithm for scoring a sentence by its words
    sentence_weight = dict()

    for sentence in sentences:
        sentence_wordcount = (len(word_tokenize(sentence)))
        sentence_wordcount_without_stop_words = 0
        for word_weight in frequency_table:
            if word_weight in sentence.lower():
                sentence_wordcount_without_stop_words += 1
                if sentence[:7] in sentence_weight:
                    sentence_weight[sentence[:7]] += frequency_table[word_weight]
                else:
                    sentence_weight[sentence[:7]] = frequency_table[word_weight]

        sentence_weight[sentence[:7]] = sentence_weight[sentence[:7]] / sentence_wordcount_without_stop_words

    return sentence_weight

def _calculate_average_score(sentence_weight):
   
    #calculating the average score for the sentences
    sum_values = 0
    for entry in sentence_weight:
        sum_values += sentence_weight[entry]
    
    average_score = (sum_values / len(sentence_weight))#getting sentence average value from source text

    return average_score

def _get_summary(sentences, sentence_weight, thres):
    
    sentence_counter = 0
    article_summary = ''

    for sentence in sentences:
        if sentence[:7] in sentence_weight and sentence_weight[sentence[:7]] >= (thres):
            article_summary += sentence
            sentence_counter += 1
    print ("summary_sentence : ", sentence_counter)
    return article_summary

def _run_summary(_text):

    frequency_table = _create_dictionary_table(_text)
    #print ('\nfrequency table',frequency_table)
    
    sentences = sent_tokenize(_text)
    #print ('\nsentences', sentences)
    
    sentence_scores = _calculate_sentence_scores(sentences, frequency_table)
    #print ('\nsentence scores',sentence_scores)
    
    threshold = _calculate_average_score(sentence_scores)
    #print ('\nthreshold',threshold)

    _text_summary = _get_summary(sentences, sentence_scores, 1.1 * threshold)
    #print ("\nsummary\n",_text_summary)

    return _text_summary

# %%
path = os.getcwd()
privacy_path = path + '/privacy policies'
summary_path = path + '/summaries/'
print (path)
# Out:
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation

# %%
files = []
for r, d, f in os.walk(privacy_path):
    for file in f:
        temp_path = os.path.join(r, file)
        if '.txt' in file and os.stat(temp_path).st_size != 0:
            files.append(temp_path)
    break
    
    
privacy_policies=[]
for file in files:
    f = open(file, 'rt')
    text=f.read()
    privacy_policies.append(text)
    f.close()

# %%
i=0
for privacy_policy in privacy_policies:
    print (files[i])
    summary_results = _run_summary(privacy_policy)
    f= open(os.path.join(summary_path , str(i) + '.txt'), "w+")
    f.write(summary_results)
    i+=1
# Out:
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5minutetypingtest.net.txt
# summary_sentence :  6
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2beesinapod.com.txt
# summary_sentence :  46
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.99boulders.com.txt
# summary_sentence :  25
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4witness.org.txt
# summary_sentence :  10
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.99damage.de.txt
# summary_sentence :  29
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1stworldtradeportal.com.txt
# summary_sentence :  5
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2cookinmamas.com.txt
# summary_sentence :  20
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.100directions.com.txt
# summary_sentence :  81
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4tests.com.txt
# summary_sentence :  31
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.6ku.com.txt
# summary_sentence :  25
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2geekswhoeat.com.txt
# summary_sentence :  34
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.45nrth.com.txt
# summary_sentence :  17
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.33communication.com.txt
# summary_sentence :  11
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.10fastfingers.com.txt
# summary_sentence :  9
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.9to5mac.com.txt
# summary_sentence :  33
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5dinners1hour.com.txt
# summary_sentence :  41
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5ivestarlondon.com.txt
# summary_sentence :  17
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2aussietravellers.com.txt
# summary_sentence :  2
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.21secolo.news.txt
# summary_sentence :  13
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.27east.com.txt
# summary_sentence :  51
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.97xonline.com.txt
# summary_sentence :  17
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.99-cent-store.com.txt
# summary_sentence :  10
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1stview.ca.txt
# summary_sentence :  8
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4-h.org.txt
# summary_sentence :  4
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.24hourslayover.com.txt
# summary_sentence :  32
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.99centrazor.com.txt
# summary_sentence :  80
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.3boysandadog.com.txt
# summary_sentence :  36
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2wired2tired.com.txt
# summary_sentence :  1
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.3littlegreenwoods.com.txt
# summary_sentence :  40
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1parkplace.com.txt
# summary_sentence :  6
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.24hrtowingsandiego.com.txt
# summary_sentence :  2
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4sonrus.com.txt
# summary_sentence :  6
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.3yummytummies.com.txt
# summary_sentence :  26
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.3dprinter.net.txt
# summary_sentence :  27
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.90min.in.txt
# summary_sentence :  31
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.20minutecook.com.txt
# summary_sentence :  21
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5dollardinners.com.txt
# summary_sentence :  81
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5littlemonsters.com.txt
# summary_sentence :  28
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.12newsnow.com.txt
# summary_sentence :  40
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.20cogs.co.uk.txt
# summary_sentence :  81
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.49ersgab.com.txt
# summary_sentence :  13
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4jehovah.org.txt
# summary_sentence :  37
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5kingsmarketing.com.txt
# summary_sentence :  27
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.7diamonds.com.txt
# summary_sentence :  24
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.11wickets.com.txt
# summary_sentence :  11
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.90min.com.txt
# summary_sentence :  34
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4pawshop.com.txt
# summary_sentence :  69
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1pureradio.com.txt
# summary_sentence :  17
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1-800courier.com.txt
# summary_sentence :  6
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1iota.com.txt
# summary_sentence :  11
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.9to5google.com.txt
# summary_sentence :  11
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2foodtrippers.com.txt
# summary_sentence :  22
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.20monroelive.com.txt
# summary_sentence :  0
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.123chinesenewyear.com.txt
# summary_sentence :  1
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.24carrotkitchen.com.txt
# summary_sentence :  46
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.5thwheelforums.com.txt
# summary_sentence :  26
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.9to5toys.com.txt
# summary_sentence :  21
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.8tracks.com.txt
# summary_sentence :  30
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4thletter.net.txt
# summary_sentence :  39
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.100things2do.ca.txt
# summary_sentence :  47
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4geniecivil.com.txt
# summary_sentence :  26
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.3dprinthq.com.txt
# summary_sentence :  7
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.2xzone.com.txt
# summary_sentence :  9
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.4hatsandfrugal.com.txt
# summary_sentence :  31
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.50marketing.com.txt
# summary_sentence :  0
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.52kitchenadventures.com.txt
# summary_sentence :  21
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.1pv.fr.txt
# summary_sentence :  21
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.12thtribe.com.txt
# summary_sentence :  81
# /home/muneeb/Semester#6/FYP-I/Mid-Evaluation/privacy policies/www.100productmanagers.com.txt
# summary_sentence :  14
